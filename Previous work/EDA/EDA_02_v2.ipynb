# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # The Dataset

# %%
msn02 = pd.read_csv("data/msn_02_fuel_leak_signals_preprocessed.csv", delimiter=';')

# %%
msn02.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623580 entries, 0 to 623579
# Data columns (total 111 columns):
#  #    Column                                Non-Null Count   Dtype
# ---   ------                                --------------   -----
#  0    UTC_TIME                              623580 non-null  object
#  1    MSN                                   623580 non-null  object
#  2    Flight                                623580 non-null  object
#  3    ENGINE_RUNNING_1                      623580 non-null  bool
#  4    ENGINE_RUNNING_2                      623580 non-null  bool
#  5    ENGINE_RUNNING_3                      623580 non-null  bool
#  6    ENGINE_RUNNING_4                      623580 non-null  bool
#  7    FLIGHT_PHASE_COUNT                    560658 non-null  float64
#  8    FUEL_FLOW_1                           514937 non-null  float64
#  9    FUEL_FLOW_2                           516594 non-null  float64
#  10   FUEL_FLOW_3                           516599 non-null  float64
#  11   FUEL_FLOW_4                           514711 non-null  float64
#  12   FUEL_PITCH                            560314 non-null  float64
#  13   FUEL_ROLL                             560314 non-null  float64
#  14   FUEL_TRANSFER_MODE_VALUE              560366 non-null  float64
#  15   FUEL_USED_1                           514944 non-null  float64
#  16   FUEL_USED_2                           516600 non-null  float64
#  17   FUEL_USED_3                           516601 non-null  float64
#  18   FUEL_USED_4                           514713 non-null  float64
#  19   FW_GEO_ALTITUDE                       560705 non-null  float64
#  20   LEAK_DETECTION_LEAK_FLOW              560305 non-null  float64
#  21   LSTU1_A_VOLUME                        560327 non-null  float64
#  22   LSTU1_F_VOLUME                        560327 non-null  float64
#  23   PITCH_ANGLE                           560730 non-null  float64
#  24   ROLL_ANGLE                            560729 non-null  float64
#  25   RSTU1_A_VOLUME                        560327 non-null  float64
#  26   RSTU1_F_VOLUME                        560327 non-null  float64
#  27   SELECTED_GADIR_ALTITUDE_VALUE         560291 non-null  float64
#  28   STATE_PMP_MAIN_FT1_ABNRM_ON           623580 non-null  bool
#  29   STATE_PMP_MAIN_FT1_IMMERSED           623580 non-null  bool
#  30   STATE_PMP_MAIN_FT1_ON                 623580 non-null  bool
#  31   STATE_PMP_MAIN_FT2_ABNRM_ON           623580 non-null  bool
#  32   STATE_PMP_MAIN_FT2_IMMERSED           623580 non-null  bool
#  33   STATE_PMP_MAIN_FT2_ON                 623580 non-null  bool
#  34   STATE_PMP_MAIN_FT3_ABNRM_ON           623580 non-null  bool
#  35   STATE_PMP_MAIN_FT3_IMMERSED           623580 non-null  bool
#  36   STATE_PMP_MAIN_FT3_ON                 623580 non-null  bool
#  37   STATE_PMP_MAIN_FT4_ABNRM_ON           623580 non-null  bool
#  38   STATE_PMP_MAIN_FT4_IMMERSED           623580 non-null  bool
#  39   STATE_PMP_MAIN_FT4_ON                 623580 non-null  bool
#  40   STATE_PMP_STBY_FT1_ABNRM_ON           623580 non-null  bool
#  41   STATE_PMP_STBY_FT1_IMMERSED           623580 non-null  bool
#  42   STATE_PMP_STBY_FT1_ON                 623580 non-null  bool
#  43   STATE_PMP_STBY_FT2_ABNRM_ON           623580 non-null  bool
#  44   STATE_PMP_STBY_FT2_IMMERSED           623580 non-null  bool
#  45   STATE_PMP_STBY_FT2_ON                 623580 non-null  bool
#  46   STATE_PMP_STBY_FT3_ABNRM_ON           623580 non-null  bool
#  47   STATE_PMP_STBY_FT3_IMMERSED           623580 non-null  bool
#  48   STATE_PMP_STBY_FT3_ON                 623580 non-null  bool
#  49   STATE_PMP_STBY_FT4_ABNRM_ON           623580 non-null  bool
#  50   STATE_PMP_STBY_FT4_IMMERSED           623580 non-null  bool
#  51   STATE_PMP_STBY_FT4_ON                 623580 non-null  bool
#  52   STATE_PMP_XFR_1_L_ABNRM_ON            623580 non-null  bool
#  53   STATE_PMP_XFR_1_L_IMMERSED            623580 non-null  bool
#  54   STATE_PMP_XFR_1_L_ON                  623580 non-null  bool
#  55   STATE_PMP_XFR_2_L_ABNRM_ON            623580 non-null  bool
#  56   STATE_PMP_XFR_2_L_IMMERSED            623580 non-null  bool
#  57   STATE_PMP_XFR_2_L_ON                  623580 non-null  bool
#  58   STATE_PMP_XFR_3_R_ABNRM_ON            623580 non-null  bool
#  59   STATE_PMP_XFR_3_R_IMMERSED            623580 non-null  bool
#  60   STATE_PMP_XFR_3_R_ON                  623580 non-null  bool
#  61   STATE_PMP_XFR_4_R_ABNRM_ON            623580 non-null  bool
#  62   STATE_PMP_XFR_4_R_IMMERSED            623580 non-null  bool
#  63   STATE_PMP_XFR_4_R_LP                  623580 non-null  bool
#  64   STATE_PMP_XFR_4_R_ON                  623580 non-null  bool
#  65   STATUS_FUEL_LEAK_DETECTED_VALID       560287 non-null  float64
#  66   TRANSFER_MODE                         207424 non-null  float64
#  67   VALUE_FOB                             560322 non-null  float64
#  68   VALUE_FUEL_QTY_CC1                    560287 non-null  float64
#  69   VALUE_FUEL_QTY_CC2                    560287 non-null  float64
#  70   VALUE_FUEL_QTY_CC3                    560287 non-null  float64
#  71   VALUE_FUEL_QTY_CC4                    560287 non-null  float64
#  72   VALUE_FUEL_QTY_CT                     560604 non-null  float64
#  73   VALUE_FUEL_QTY_FT1                    560610 non-null  float64
#  74   VALUE_FUEL_QTY_FT2                    560609 non-null  float64
#  75   VALUE_FUEL_QTY_FT3                    560610 non-null  float64
#  76   VALUE_FUEL_QTY_FT4                    560607 non-null  float64
#  77   VALUE_FUEL_QTY_LXT                    560606 non-null  float64
#  78   VALUE_FUEL_QTY_RXT                    560610 non-null  float64
#  79   day                                   623580 non-null  int64
#  80   month                                 623580 non-null  int64
#  81   time                                  623580 non-null  object
#  82   year                                  623580 non-null  int64
#  83   APU_FUEL_FLOW_REQUEST_SIGNAL_1        171032 non-null  float64
#  84   EF1_Density                           560322 non-null  float64
#  85   EF4_Density                           560319 non-null  float64
#  86   RESOLVED_STATE_V_D                    623580 non-null  bool
#  87   RESOLVED_STATE_V_LP1                  623580 non-null  bool
#  88   RESOLVED_STATE_V_LP2                  623580 non-null  bool
#  89   RESOLVED_STATE_V_LP3                  623580 non-null  bool
#  90   RESOLVED_STATE_V_LP4                  623580 non-null  bool
#  91   RESOLVED_STATE_V_RM                   623580 non-null  bool
#  92   RESOLVED_STATE_V_RP                   623580 non-null  bool
#  93   RESOLVED_STATE_V_T1                   623580 non-null  bool
#  94   RESOLVED_STATE_V_T2                   623580 non-null  bool
#  95   RESOLVED_STATE_V_T3                   623580 non-null  bool
#  96   RESOLVED_STATE_V_T4                   623580 non-null  bool
#  97   RESOLVED_STATE_V_X1                   623580 non-null  bool
#  98   RESOLVED_STATE_V_X2                   623580 non-null  bool
#  99   RESOLVED_STATE_V_X3                   623580 non-null  bool
#  100  RESOLVED_STATE_V_X4                   623580 non-null  bool
#  101  STATE_FUEL_QTY_ACCURACY_LST_DEGRADED  623580 non-null  bool
#  102  STATE_FUEL_QTY_ACCURACY_RST_DEGRADED  623580 non-null  bool
#  103  STATUS_FUEL_QTY_PART_UNUSABLE_LST     560277 non-null  float64
#  104  STATUS_FUEL_QTY_PART_UNUSABLE_RST     560277 non-null  float64
#  105  STATUS_FUEL_QTY_UNUSABLE_LST          560287 non-null  float64
#  106  STATUS_FUEL_QTY_UNUSABLE_RST          560287 non-null  float64
#  107  STATUS_OVERFLOW_LST                   560287 non-null  float64
#  108  STATUS_OVERFLOW_RST                   560287 non-null  float64
#  109  VALUE_FUEL_VOL_LST                    560315 non-null  float64
#  110  VALUE_FUEL_VOL_RST                    560305 non-null  float64
# dtypes: bool(58), float64(46), int64(3), object(4)
# memory usage: 286.6+ MB

# %%
# Setting index as datetime
msn02['UTC_TIME'] = pd.to_datetime(msn02['UTC_TIME'])
msn02 = msn02.set_index("UTC_TIME")

# %%
msn02 = msn02.sort_index()

# %%
# Dropping Duplicates
msn02 = msn02.drop_duplicates()

# %%
msn02.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 610106 entries, 2010-10-26 12:56:13 to 2017-01-23 20:28:35
# Data columns (total 110 columns):
#  #    Column                                Non-Null Count   Dtype
# ---   ------                                --------------   -----
#  0    MSN                                   610106 non-null  object
#  1    Flight                                610106 non-null  object
#  2    ENGINE_RUNNING_1                      610106 non-null  bool
#  3    ENGINE_RUNNING_2                      610106 non-null  bool
#  4    ENGINE_RUNNING_3                      610106 non-null  bool
#  5    ENGINE_RUNNING_4                      610106 non-null  bool
#  6    FLIGHT_PHASE_COUNT                    547185 non-null  float64
#  7    FUEL_FLOW_1                           503789 non-null  float64
#  8    FUEL_FLOW_2                           504961 non-null  float64
#  9    FUEL_FLOW_3                           504966 non-null  float64
#  10   FUEL_FLOW_4                           503563 non-null  float64
#  11   FUEL_PITCH                            546841 non-null  float64
#  12   FUEL_ROLL                             546841 non-null  float64
#  13   FUEL_TRANSFER_MODE_VALUE              546893 non-null  float64
#  14   FUEL_USED_1                           503796 non-null  float64
#  15   FUEL_USED_2                           504967 non-null  float64
#  16   FUEL_USED_3                           504968 non-null  float64
#  17   FUEL_USED_4                           503565 non-null  float64
#  18   FW_GEO_ALTITUDE                       547232 non-null  float64
#  19   LEAK_DETECTION_LEAK_FLOW              546832 non-null  float64
#  20   LSTU1_A_VOLUME                        546854 non-null  float64
#  21   LSTU1_F_VOLUME                        546854 non-null  float64
#  22   PITCH_ANGLE                           547257 non-null  float64
#  23   ROLL_ANGLE                            547256 non-null  float64
#  24   RSTU1_A_VOLUME                        546854 non-null  float64
#  25   RSTU1_F_VOLUME                        546854 non-null  float64
#  26   SELECTED_GADIR_ALTITUDE_VALUE         546818 non-null  float64
#  27   STATE_PMP_MAIN_FT1_ABNRM_ON           610106 non-null  bool
#  28   STATE_PMP_MAIN_FT1_IMMERSED           610106 non-null  bool
#  29   STATE_PMP_MAIN_FT1_ON                 610106 non-null  bool
#  30   STATE_PMP_MAIN_FT2_ABNRM_ON           610106 non-null  bool
#  31   STATE_PMP_MAIN_FT2_IMMERSED           610106 non-null  bool
#  32   STATE_PMP_MAIN_FT2_ON                 610106 non-null  bool
#  33   STATE_PMP_MAIN_FT3_ABNRM_ON           610106 non-null  bool
#  34   STATE_PMP_MAIN_FT3_IMMERSED           610106 non-null  bool
#  35   STATE_PMP_MAIN_FT3_ON                 610106 non-null  bool
#  36   STATE_PMP_MAIN_FT4_ABNRM_ON           610106 non-null  bool
#  37   STATE_PMP_MAIN_FT4_IMMERSED           610106 non-null  bool
#  38   STATE_PMP_MAIN_FT4_ON                 610106 non-null  bool
#  39   STATE_PMP_STBY_FT1_ABNRM_ON           610106 non-null  bool
#  40   STATE_PMP_STBY_FT1_IMMERSED           610106 non-null  bool
#  41   STATE_PMP_STBY_FT1_ON                 610106 non-null  bool
#  42   STATE_PMP_STBY_FT2_ABNRM_ON           610106 non-null  bool
#  43   STATE_PMP_STBY_FT2_IMMERSED           610106 non-null  bool
#  44   STATE_PMP_STBY_FT2_ON                 610106 non-null  bool
#  45   STATE_PMP_STBY_FT3_ABNRM_ON           610106 non-null  bool
#  46   STATE_PMP_STBY_FT3_IMMERSED           610106 non-null  bool
#  47   STATE_PMP_STBY_FT3_ON                 610106 non-null  bool
#  48   STATE_PMP_STBY_FT4_ABNRM_ON           610106 non-null  bool
#  49   STATE_PMP_STBY_FT4_IMMERSED           610106 non-null  bool
#  50   STATE_PMP_STBY_FT4_ON                 610106 non-null  bool
#  51   STATE_PMP_XFR_1_L_ABNRM_ON            610106 non-null  bool
#  52   STATE_PMP_XFR_1_L_IMMERSED            610106 non-null  bool
#  53   STATE_PMP_XFR_1_L_ON                  610106 non-null  bool
#  54   STATE_PMP_XFR_2_L_ABNRM_ON            610106 non-null  bool
#  55   STATE_PMP_XFR_2_L_IMMERSED            610106 non-null  bool
#  56   STATE_PMP_XFR_2_L_ON                  610106 non-null  bool
#  57   STATE_PMP_XFR_3_R_ABNRM_ON            610106 non-null  bool
#  58   STATE_PMP_XFR_3_R_IMMERSED            610106 non-null  bool
#  59   STATE_PMP_XFR_3_R_ON                  610106 non-null  bool
#  60   STATE_PMP_XFR_4_R_ABNRM_ON            610106 non-null  bool
#  61   STATE_PMP_XFR_4_R_IMMERSED            610106 non-null  bool
#  62   STATE_PMP_XFR_4_R_LP                  610106 non-null  bool
#  63   STATE_PMP_XFR_4_R_ON                  610106 non-null  bool
#  64   STATUS_FUEL_LEAK_DETECTED_VALID       546814 non-null  float64
#  65   TRANSFER_MODE                         193951 non-null  float64
#  66   VALUE_FOB                             546849 non-null  float64
#  67   VALUE_FUEL_QTY_CC1                    546814 non-null  float64
#  68   VALUE_FUEL_QTY_CC2                    546814 non-null  float64
#  69   VALUE_FUEL_QTY_CC3                    546814 non-null  float64
#  70   VALUE_FUEL_QTY_CC4                    546814 non-null  float64
#  71   VALUE_FUEL_QTY_CT                     547131 non-null  float64
#  72   VALUE_FUEL_QTY_FT1                    547137 non-null  float64
#  73   VALUE_FUEL_QTY_FT2                    547136 non-null  float64
#  74   VALUE_FUEL_QTY_FT3                    547137 non-null  float64
#  75   VALUE_FUEL_QTY_FT4                    547134 non-null  float64
#  76   VALUE_FUEL_QTY_LXT                    547133 non-null  float64
#  77   VALUE_FUEL_QTY_RXT                    547137 non-null  float64
#  78   day                                   610106 non-null  int64
#  79   month                                 610106 non-null  int64
#  80   time                                  610106 non-null  object
#  81   year                                  610106 non-null  int64
#  82   APU_FUEL_FLOW_REQUEST_SIGNAL_1        166829 non-null  float64
#  83   EF1_Density                           546849 non-null  float64
#  84   EF4_Density                           546846 non-null  float64
#  85   RESOLVED_STATE_V_D                    610106 non-null  bool
#  86   RESOLVED_STATE_V_LP1                  610106 non-null  bool
#  87   RESOLVED_STATE_V_LP2                  610106 non-null  bool
#  88   RESOLVED_STATE_V_LP3                  610106 non-null  bool
#  89   RESOLVED_STATE_V_LP4                  610106 non-null  bool
#  90   RESOLVED_STATE_V_RM                   610106 non-null  bool
#  91   RESOLVED_STATE_V_RP                   610106 non-null  bool
#  92   RESOLVED_STATE_V_T1                   610106 non-null  bool
#  93   RESOLVED_STATE_V_T2                   610106 non-null  bool
#  94   RESOLVED_STATE_V_T3                   610106 non-null  bool
#  95   RESOLVED_STATE_V_T4                   610106 non-null  bool
#  96   RESOLVED_STATE_V_X1                   610106 non-null  bool
#  97   RESOLVED_STATE_V_X2                   610106 non-null  bool
#  98   RESOLVED_STATE_V_X3                   610106 non-null  bool
#  99   RESOLVED_STATE_V_X4                   610106 non-null  bool
#  100  STATE_FUEL_QTY_ACCURACY_LST_DEGRADED  610106 non-null  bool
#  101  STATE_FUEL_QTY_ACCURACY_RST_DEGRADED  610106 non-null  bool
#  102  STATUS_FUEL_QTY_PART_UNUSABLE_LST     546804 non-null  float64
#  103  STATUS_FUEL_QTY_PART_UNUSABLE_RST     546804 non-null  float64
#  104  STATUS_FUEL_QTY_UNUSABLE_LST          546814 non-null  float64
#  105  STATUS_FUEL_QTY_UNUSABLE_RST          546814 non-null  float64
#  106  STATUS_OVERFLOW_LST                   546814 non-null  float64
#  107  STATUS_OVERFLOW_RST                   546814 non-null  float64
#  108  VALUE_FUEL_VOL_LST                    546842 non-null  float64
#  109  VALUE_FUEL_VOL_RST                    546832 non-null  float64
# dtypes: bool(58), float64(46), int64(3), object(3)
# memory usage: 280.4+ MB

# %%
# Keeping only relevant columns

# Same as those available in the other MSNs except for added VALUE_FUEL_QTYCCx
columns = ['MSN', 
           'Flight',
           'FLIGHT_PHASE_COUNT','FUEL_USED_1','FUEL_USED_2', 'FUEL_USED_3', 'FUEL_USED_4', 
           'FW_GEO_ALTITUDE',
           'VALUE_FOB', 
           'VALUE_FUEL_QTY_CC1', 'VALUE_FUEL_QTY_CC2', 'VALUE_FUEL_QTY_CC3', 'VALUE_FUEL_QTY_CC4', 'VALUE_FUEL_QTY_CT', 
           'VALUE_FUEL_QTY_FT1', 'VALUE_FUEL_QTY_FT2', 'VALUE_FUEL_QTY_FT3', 'VALUE_FUEL_QTY_FT4', 
           'VALUE_FUEL_QTY_LXT', 'VALUE_FUEL_QTY_RXT',
           'LEAK_DETECTION_LEAK_FLOW', 'STATUS_FUEL_LEAK_DETECTED_VALID'
           ]

df = msn02[columns]

# %%
# Dropping all rows with nulls
df = df.dropna(subset=columns)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 503467 entries, 2010-10-26 12:56:15 to 2017-01-23 20:28:33
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   MSN                              503467 non-null  object
#  1   Flight                           503467 non-null  object
#  2   FLIGHT_PHASE_COUNT               503467 non-null  float64
#  3   FUEL_USED_1                      503467 non-null  float64
#  4   FUEL_USED_2                      503467 non-null  float64
#  5   FUEL_USED_3                      503467 non-null  float64
#  6   FUEL_USED_4                      503467 non-null  float64
#  7   FW_GEO_ALTITUDE                  503467 non-null  float64
#  8   VALUE_FOB                        503467 non-null  float64
#  9   VALUE_FUEL_QTY_CC1               503467 non-null  float64
#  10  VALUE_FUEL_QTY_CC2               503467 non-null  float64
#  11  VALUE_FUEL_QTY_CC3               503467 non-null  float64
#  12  VALUE_FUEL_QTY_CC4               503467 non-null  float64
#  13  VALUE_FUEL_QTY_CT                503467 non-null  float64
#  14  VALUE_FUEL_QTY_FT1               503467 non-null  float64
#  15  VALUE_FUEL_QTY_FT2               503467 non-null  float64
#  16  VALUE_FUEL_QTY_FT3               503467 non-null  float64
#  17  VALUE_FUEL_QTY_FT4               503467 non-null  float64
#  18  VALUE_FUEL_QTY_LXT               503467 non-null  float64
#  19  VALUE_FUEL_QTY_RXT               503467 non-null  float64
#  20  LEAK_DETECTION_LEAK_FLOW         503467 non-null  float64
#  21  STATUS_FUEL_LEAK_DETECTED_VALID  503467 non-null  float64
# dtypes: float64(20), object(2)
# memory usage: 88.3+ MB

# %% [markdown]
# # The two possible target variables

# %% [markdown]
# ### `STATUS_FUEL_LEAK_DETECTED_VALID`

# %%
df['STATUS_FUEL_LEAK_DETECTED_VALID'].value_counts()
# Out:
# STATUS_FUEL_LEAK_DETECTED_VALID
# 1.0    503384
# 0.0        83
# Name: count, dtype: int64

# %%
# Assuming df is your DataFrame
status_counts = df['STATUS_FUEL_LEAK_DETECTED_VALID'].value_counts()

# Create the bar chart
plt.figure(figsize=(6, 4))
bars = status_counts.plot(kind='bar')

# Add labels and title
plt.title('Fuel Leak Detected Status')
plt.xlabel('Status (0 = Leak, 1 = No Leak Detected)')
plt.ylabel('Count')
plt.xticks(rotation=0)

# Annotate the bars with the numbers
for i, value in enumerate(status_counts):
    plt.text(i, value + 0.1, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### `LEAK_DETECTION_LEAK_FLOW`

# %%
plt.figure(figsize=(6, 4))
plt.hist(df['LEAK_DETECTION_LEAK_FLOW'], bins=50)
plt.xlabel("Freaquency")
plt.ylabel("Value")
plt.title("Histogram of Fuel Leak Detection")
plt.show()

# %%
df['LEAK_DETECTION_LEAK_FLOW'].describe()
# Out:
# count    503467.000000
# mean        -63.237622
# std        2619.548138
# min      -82781.590000
# 25%        -162.348150
# 50%           0.000000
# 75%         142.510750
# max       73028.340000
# Name: LEAK_DETECTION_LEAK_FLOW, dtype: float64

# %%
df['LEAK_DETECTION_LEAK_FLOW'].value_counts()
# Out:
# LEAK_DETECTION_LEAK_FLOW
# 0.00000        82859
# 326.19430      12589
# 125.41090       5094
# 10302.26000       43
# 74.28348           8
#                ...
# 8483.42500         1
# 7880.47500         1
# 7456.26100         1
# 6863.49300         1
# 31.75000           1
# Name: count, Length: 372998, dtype: int64

# %% [markdown]
# #### Setting possible threshold

# %%
threshold = 20000 # Change as needed
df['LEAK_FLOW_FLAG'] = (df['LEAK_DETECTION_LEAK_FLOW'] > threshold).astype(int)

# %%
status_counts = df['LEAK_FLOW_FLAG'].value_counts()

# Create the bar chart
plt.figure(figsize=(6, 4))
bars = status_counts.plot(kind='bar')

# Add labels and title
plt.title('Leak Flow Below / Above 20,000 threshold')
plt.xlabel('Status (0 = Flow below threshold, 1 = Flow above threshold)')
plt.ylabel('Count')
plt.xticks(rotation=0)

# Annotate the bars with the numbers
for i, value in enumerate(status_counts):
    plt.text(i, value + 0.1, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # Feature Enginneering

# %% [markdown]
# ### Fuel Discprepancy Equation 1

# %%
# Identify Different Flights within the same flight number
# ========================================================

# Identify when a new flight starts (FLIGHT_PHASE_COUNT resets within each Flight)
df['NEW_FLIGHT'] = df.groupby('Flight')['FLIGHT_PHASE_COUNT'].diff().lt(0)

# Assign a unique flight instance number per Flight
df['FLIGHT_INSTANCE'] = df.groupby('Flight')['NEW_FLIGHT'].cumsum()

# New column to identify unique flights
df['FLIGHT_ID'] = df['Flight'].astype(str) + "_" + df['FLIGHT_INSTANCE'].astype(str)

# %%
# Filter out only fro flight phase 8 - Cruise
df = df[df["FLIGHT_PHASE_COUNT"]==8.0]

# %%
# Calculating Fuel Discrepancy
# ============================

# Sort by time
df = df.sort_index()

# Find the initial fuel value for each flight instance
df['1START_FOB'] = df.groupby('FLIGHT_ID')['VALUE_FOB'].transform('first')

# Calculate the total fuel used
df['TOTAL_FUEL_USED'] = df['FUEL_USED_1'] + df['FUEL_USED_2'] + df['FUEL_USED_3'] + df['FUEL_USED_4']

# Calcuate expected fuel on board
df['1EXPECTED_FOB'] = df['1START_FOB'] - df['TOTAL_FUEL_USED']

# Find Fuel Discrepancy between expected value and current value
df["1FOB_DIFFERENCE"] = (df['1EXPECTED_FOB'] - df['VALUE_FOB']).abs()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['1FOB_DIFFERENCE'])
plt.title('Box Plot of 1FOB_DIFFERENCE')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["1FOB_DIFFERENCE"], bins=40, kde=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['1FOB_DIFFERENCE'].describe()
# Out:
# count    383560.000000
# mean       1225.510783
# std        1793.125501
# min           0.017000
# 25%         490.156750
# 50%         689.743000
# 75%         975.440000
# max       25868.452000
# Name: 1FOB_DIFFERENCE, dtype: float64

# %% [markdown]
# #### FOB_DIFFERENCE DENSITY GRAPHS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# With STATUS_FUEL_LEAK_DETECTED_VALID
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 0]['1FOB_DIFFERENCE'], 
            label="Leak (0)", fill=True, alpha=0.5, ax=axes[0], color='red')
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 1]['1FOB_DIFFERENCE'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[0], color='blue')

# Labels and title
axes[0].set_xlabel("1FOB_DIFFERENCE")
axes[0].set_ylabel("Density")
axes[0].set_title("Density Plot of 1FOB_DIFFERENCE\nby STATUS_FUEL_LEAK_DETECTED_VALID")
axes[0].legend()
axes[0].grid(True)

# With LEAK_FLOW_FLAG
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 0]['1FOB_DIFFERENCE'], 
            label="No Leak (0)", fill=True, alpha=0.5, ax=axes[1], color='blue')
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 1]['1FOB_DIFFERENCE'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[1], color='red')

# Labels and title
axes[1].set_xlabel("1FOB_DIFFERENCE")
axes[1].set_ylabel("Density")
axes[1].set_title("Density Plot of 1FOB_DIFFERENCE\nby LEAK_FLOW_FLAG")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Fuel Discprepancy Equation 2

# %%
# Start amount of fuel on board
df['START_FOB'] = df.groupby('Flight')['VALUE_FOB'].transform('first')

# Total amount of fuel in tanks
df['FUEL_IN_TANKS'] = df['VALUE_FUEL_QTY_CT'] + df['VALUE_FUEL_QTY_CC1'] + df['VALUE_FUEL_QTY_CC2'] + df['VALUE_FUEL_QTY_CC3'] + df['VALUE_FUEL_QTY_CC4'] + df['VALUE_FUEL_QTY_FT1'] + df['VALUE_FUEL_QTY_FT2'] + df['VALUE_FUEL_QTY_FT3'] + df['VALUE_FUEL_QTY_FT4'] + df['VALUE_FUEL_QTY_LXT'] + df['VALUE_FUEL_QTY_RXT']

# Find the total amount of fuel used
df['TOTAL_FUEL_USED'] = df['FUEL_USED_1'] + df['FUEL_USED_2'] + df['FUEL_USED_3'] + df['FUEL_USED_4']

# Find expected amount of fuel on board (Starting amount of fuel - total fuel used at that point)
df['EXPECTED_FOB'] = df['FUEL_IN_TANKS'] - df['TOTAL_FUEL_USED']

# Finding the discrepancy of what is on board and what is expected to be on board
df["FOB_DIFFERENCE"] = (df['EXPECTED_FOB'] - df['VALUE_FOB']).abs()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['FOB_DIFFERENCE'])
plt.title('Box Plot of FOB_DIFFERENCE')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["FOB_DIFFERENCE"], bins=40, kde=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='FOB_DIFFERENCE', ylabel='Count'>

# %%
df["FOB_DIFFERENCE"].describe()
# Out:
# count    383560.000000
# mean       7303.041047
# std        5168.038678
# min           0.000300
# 25%        2992.521675
# 50%        6406.779500
# 75%       10914.692000
# max       21275.552000
# Name: FOB_DIFFERENCE, dtype: float64

# %% [markdown]
# #### FOB_DIFFERENCE DENSITY GRAPHS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# With STATUS_FUEL_LEAK_DETECTED_VALID
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 0]['FOB_DIFFERENCE'], 
            label="Leak (0)", fill=True, alpha=0.5, ax=axes[0], color='red')
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 1]['FOB_DIFFERENCE'], 
            label="No Leak (1)", fill=True, alpha=0.5, ax=axes[0], color='blue')

# Labels and title
axes[0].set_xlabel("FOB_DIFFERENCE")
axes[0].set_ylabel("Density")
axes[0].set_title("Density Plot of FOB_DIFFERENCE\nby STATUS_FUEL_LEAK_DETECTED_VALID")
axes[0].legend()
axes[0].grid(True)

# With LEAK_FLOW_FLAG
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 0]['FOB_DIFFERENCE'], 
            label="No Leak (0)", fill=True, alpha=0.5, ax=axes[1], color='blue')
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 1]['FOB_DIFFERENCE'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[1], color='red')

# Labels and title
axes[1].set_xlabel("FOB_DIFFERENCE")
axes[1].set_ylabel("Density")
axes[1].set_title("Density Plot of FOB_DIFFERENCE\nby LEAK_FLOW_FLAG")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Discrepancy between given `VALUE_FOB` and our own calculations of fuel on board

# %%
df['CALC_VALUE_FOB_DIFF'] =  df['FUEL_IN_TANKS'] - df['VALUE_FOB']

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['CALC_VALUE_FOB_DIFF'])
plt.title('Box Plot of CALC_VALUE_FOB_DIFF')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["CALC_VALUE_FOB_DIFF"], bins=20, kde=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df["CALC_VALUE_FOB_DIFF"].describe()
# Out:
# count    383560.000000
# mean       1210.005120
# std          40.998779
# min           0.000000
# 25%        1187.000000
# 50%        1221.000000
# 75%        1240.000000
# max        1288.000000
# Name: CALC_VALUE_FOB_DIFF, dtype: float64

# %% [markdown]
# #### CALC_VALUE_FOB_DIFF DENSITY GRAPHS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# With STATUS_FUEL_LEAK_DETECTED_VALID
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 0]['CALC_VALUE_FOB_DIFF'], 
            label="Leak (0)", fill=True, alpha=0.5, ax=axes[0], color='red')
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 1]['CALC_VALUE_FOB_DIFF'], 
            label="No Leak (1)", fill=True, alpha=0.5, ax=axes[0], color='blue')

# Labels and title
axes[0].set_xlabel("CALC_VALUE_FOB_DIFF")
axes[0].set_ylabel("Density")
axes[0].set_title("Density Plot of CALC_VALUE_FOB_DIFF\nby STATUS_FUEL_LEAK_DETECTED_VALID")
axes[0].legend()
axes[0].grid(True)

# With LEAK_FLOW_FLAG
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 0]['CALC_VALUE_FOB_DIFF'], 
            label="No Leak (0)", fill=True, alpha=0.5, ax=axes[1], color='blue')
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 1]['CALC_VALUE_FOB_DIFF'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[1], color='red')

# Labels and title
axes[1].set_xlabel("CALC_VALUE_FOB_DIFF")
axes[1].set_ylabel("Density")
axes[1].set_title("Density Plot of CALC_VALUE_FOB_DIFF\nby LEAK_FLOW_FLAG")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Calculating Fuel imbalance between left and right wings

# %%
# Total Fuel in Left and Right Wing
df['TOTAL_FUEL_LW'] = (df['VALUE_FUEL_QTY_LXT'] + df['VALUE_FUEL_QTY_FT1'] + df['VALUE_FUEL_QTY_FT2'])
df['TOTAL_FUEL_RW'] = (df['VALUE_FUEL_QTY_RXT'] + df['VALUE_FUEL_QTY_FT3'] + df['VALUE_FUEL_QTY_FT4'])

# Fuel Difference
df['LW_RW_DIFF'] = (df['TOTAL_FUEL_LW'] - df['TOTAL_FUEL_RW']).abs()

# %%
plt.figure(figsize=(6,4))  
sns.boxplot(x=df['LW_RW_DIFF'])
plt.title('Box Plot of LW_RW_DIFF')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["LW_RW_DIFF"], bins=40, kde=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df["LW_RW_DIFF"].describe()
# Out:
# count    383560.000000
# mean        401.334349
# std         716.852748
# min           0.000000
# 25%          67.000000
# 50%         144.000000
# 75%         412.000000
# max        4895.000000
# Name: LW_RW_DIFF, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# With STATUS_FUEL_LEAK_DETECTED_VALID
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 0]['LW_RW_DIFF'], 
            label="Leak (0)", fill=True, alpha=0.5, ax=axes[0], color='red')
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 1]['LW_RW_DIFF'], 
            label="No Leak (1)", fill=True, alpha=0.5, ax=axes[0], color='blue')

# Labels and title
axes[0].set_xlabel("LW_RW_DIFF")
axes[0].set_ylabel("Density")
axes[0].set_title("Density Plot of LW_RW_DIFF\nby STATUS_FUEL_LEAK_DETECTED_VALID")
axes[0].legend()
axes[0].grid(True)

# With LEAK_FLOW_FLAG
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 0]['LW_RW_DIFF'], 
            label="No Leak (0)", fill=True, alpha=0.5, ax=axes[1], color='blue')
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 1]['LW_RW_DIFF'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[1], color='red')

# Labels and title
axes[1].set_xlabel("LW_RW_DIFF")
axes[1].set_ylabel("Density")
axes[1].set_title("Density Plot of LW_RW_DIFF\nby LEAK_FLOW_FLAG")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # EDA

# %% [markdown]
# ### `FW_GEO_ALTITUDE`

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['FW_GEO_ALTITUDE'])
plt.title('Box Plot of FW_GEO_ALTITUDE')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["FW_GEO_ALTITUDE"], bins=40, kde=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# With STATUS_FUEL_LEAK_DETECTED_VALID
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 0]['FW_GEO_ALTITUDE'], 
            label="Leak (0)", fill=True, alpha=0.5, ax=axes[0], color='red')
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 1]['FW_GEO_ALTITUDE'], 
            label="No Leak (1)", fill=True, alpha=0.5, ax=axes[0], color='blue')

# Labels and title
axes[0].set_xlabel("FW_GEO_ALTITUDE")
axes[0].set_ylabel("Density")
axes[0].set_title("Density Plot of FW_GEO_ALTITUDE\nby STATUS_FUEL_LEAK_DETECTED_VALID")
axes[0].legend()
axes[0].grid(True)

# With LEAK_FLOW_FLAG
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 0]['FW_GEO_ALTITUDE'], 
            label="No Leak (0)", fill=True, alpha=0.5, ax=axes[1], color='blue')
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 1]['FW_GEO_ALTITUDE'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[1], color='red')

# Labels and title
axes[1].set_xlabel("FW_GEO_ALTITUDE")
axes[1].set_ylabel("Density")
axes[1].set_title("Density Plot of FW_GEO_ALTITUDE\nby LEAK_FLOW_FLAG")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### `TOTAL_FUEL_USED`

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['TOTAL_FUEL_USED'])
plt.title('Box Plot of TOTAL_FUEL_USED')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["TOTAL_FUEL_USED"], bins=40, kde=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# With STATUS_FUEL_LEAK_DETECTED_VALID
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 0]['TOTAL_FUEL_USED'], 
            label="Leak (0)", fill=True, alpha=0.5, ax=axes[0], color='red')
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 1]['TOTAL_FUEL_USED'], 
            label="No Leak (1)", fill=True, alpha=0.5, ax=axes[0], color='blue')

# Labels and title
axes[0].set_xlabel("TOTAL_FUEL_USED")
axes[0].set_ylabel("Density")
axes[0].set_title("Density Plot of TOTAL_FUEL_USED\nby STATUS_FUEL_LEAK_DETECTED_VALID")
axes[0].legend()
axes[0].grid(True)

# With LEAK_FLOW_FLAG
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 0]['TOTAL_FUEL_USED'], 
            label="No Leak (0)", fill=True, alpha=0.5, ax=axes[1], color='blue')
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 1]['TOTAL_FUEL_USED'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[1], color='red')

# Labels and title
axes[1].set_xlabel("TOTAL_FUEL_USED")
axes[1].set_ylabel("Density")
axes[1].set_title("Density Plot of TOTAL_FUEL_USED\nby LEAK_FLOW_FLAG")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### `VALUE_FOB`

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['VALUE_FOB'])
plt.title('Box Plot of VALUE_FOB')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["VALUE_FOB"], bins=40, kde=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# With STATUS_FUEL_LEAK_DETECTED_VALID
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 0]['VALUE_FOB'], 
            label="Leak (0)", fill=True, alpha=0.5, ax=axes[0], color='red')
sns.kdeplot(df[df['STATUS_FUEL_LEAK_DETECTED_VALID'] == 1]['VALUE_FOB'], 
            label="No Leak (1)", fill=True, alpha=0.5, ax=axes[0], color='blue')

# Labels and title
axes[0].set_xlabel("VALUE_FOB")
axes[0].set_ylabel("Density")
axes[0].set_title("Density Plot of VALUE_FOB\nby STATUS_FUEL_LEAK_DETECTED_VALID")
axes[0].legend()
axes[0].grid(True)

# With LEAK_FLOW_FLAG
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 0]['VALUE_FOB'], 
            label="No Leak (0)", fill=True, alpha=0.5, ax=axes[1], color='blue')
sns.kdeplot(df[df['LEAK_FLOW_FLAG'] == 1]['VALUE_FOB'], 
            label="Leak (1)", fill=True, alpha=0.5, ax=axes[1], color='red')

# Labels and title
axes[1].set_xlabel("VALUE_FOB")
axes[1].set_ylabel("Density")
axes[1].set_title("Density Plot of VALUE_FOB\nby LEAK_FLOW_FLAG")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### `VALUE_FOB` vs `EXPECTED_FOB`

# %%
# WITH EQUATION 1
flights_to_plot = df['FLIGHT_ID'].unique()[:7]

# Initialize counter
counter = 0

# Set up the number of rows and columns for subplots
rows = 2  # you can change this based on the number of flights
cols = 3  # you can change this based on the number of flights

# Create a figure with subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

# Flatten the axes array for easy iteration (if it's 2D)
axes = axes.flatten()

# For each unique flight
for idx, flight in enumerate(flights_to_plot[1:]):  # skipping the first flight
    # Filter data for that flight
    flight_data = df[df['FLIGHT_ID'] == flight]
    
    # Select the current subplot axis
    ax = axes[idx]
    
    # Plot the actual fuel on board (VALUE_FOB) vs expected fuel on board (EXPECTED_FOB)
    ax.plot(flight_data.index, flight_data['VALUE_FOB'], label=f'VALUE_FOB - Flight {flight}', color='blue')
    ax.plot(flight_data.index, flight_data['1EXPECTED_FOB'], label=f'1EXPECTED_FOB - Flight {flight}', color='red')
    
    # Set the title and labels for the subplot
    ax.set_title(f'VALUE_FOB vs 1EXPECTED_FOB for Flight {flight}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Fuel (FOB)')
    
    # Add legend
    ax.legend()
    
    # Show grid
    ax.grid(True)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# WITH EQUATION 2
flights_to_plot = df['Flight'].unique()[:7]

# Initialize counter
counter = 0

# Set up the number of rows and columns for subplots
rows = 2  # you can change this based on the number of flights
cols = 3  # you can change this based on the number of flights

# Create a figure with subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

# Flatten the axes array for easy iteration (if it's 2D)
axes = axes.flatten()

# For each unique flight
for idx, flight in enumerate(flights_to_plot[1:]):  # skipping the first flight
    # Filter data for that flight
    flight_data = df[df['Flight'] == flight]
    
    # Select the current subplot axis
    ax = axes[idx]
    
    # Plot the actual fuel on board (VALUE_FOB) vs expected fuel on board (EXPECTED_FOB)
    ax.plot(flight_data.index, flight_data['VALUE_FOB'], label=f'VALUE_FOB - Flight {flight}', color='blue')
    ax.plot(flight_data.index, flight_data['EXPECTED_FOB'], label=f'EXPECTED_FOB - Flight {flight}', color='red')
    
    # Set the title and labels for the subplot
    ax.set_title(f'VALUE_FOB vs EXPECTED_FOB for Flight {flight}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Fuel (FOB)')
    
    # Add legend
    ax.legend()
    
    # Show grid
    ax.grid(True)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### `START FOB` vs `TOTAL_FUEL_USED` + `VALUE_FOB`
# Should be equal

# %%
# Equation 1
flights_to_plot = df['FLIGHT_ID'].unique()[:7]

# Initialize counter
counter = 0

# Set up the number of rows and columns for subplots
rows = 2 
cols = 3  

# Create a figure with subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

# Flatten the axes array for easy iteration (if it's 2D)
axes = axes.flatten()

# For each unique flight
for idx, flight in enumerate(flights_to_plot[1:]):  # Skipping the first flight for the plot
    if counter == 7:
        break

    # Filter data for that flight
    flight_data = df[df['FLIGHT_ID'] == flight]
    
    # Select the current subplot axis
    ax = axes[idx]
    
    # Plot the START_FOB
    ax.plot(flight_data.index, flight_data['1START_FOB'], label=f'1START_FOB - Flight {flight}', color='green')
    
    # Calculate TOTAL_FUEL_USED + VALUE_FOB for the entire flight
    total_fuel_used_plus_fob = flight_data['TOTAL_FUEL_USED'] + flight_data['VALUE_FOB']
    
    # Plot the TOTAL_FUEL_USED + VALUE_FOB
    ax.plot(flight_data.index, total_fuel_used_plus_fob, label=f'TOTAL_FUEL_USED + VALUE_FOB - Flight {flight}', color='orange')
    
    # Set the title and labels for the subplot
    ax.set_title(f'START_FOB vs (TOTAL_FUEL_USED + VALUE_FOB) for Flight {flight}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Fuel (FOB)')
    
    # Add legend
    ax.legend()
    
    # Show grid
    ax.grid(True)

    # Increment counter
    counter += 1

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# EQUATION 2
flights_to_plot = df['Flight'].unique()[:7]

# Initialize counter
counter = 0

# Set up the number of rows and columns for subplots
rows = 2 
cols = 3  

# Create a figure with subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

# Flatten the axes array for easy iteration (if it's 2D)
axes = axes.flatten()

# For each unique flight
for idx, flight in enumerate(flights_to_plot[1:]):  # Skipping the first flight for the plot
    if counter == 7:
        break

    # Filter data for that flight
    flight_data = df[df['Flight'] == flight]
    
    # Select the current subplot axis
    ax = axes[idx]
    
    # Plot the START_FOB
    ax.plot(flight_data.index, flight_data['START_FOB'], label=f'START_FOB - Flight {flight}', color='green')
    
    # Calculate TOTAL_FUEL_USED + VALUE_FOB for the entire flight
    total_fuel_used_plus_fob = flight_data['TOTAL_FUEL_USED'] + flight_data['VALUE_FOB']
    
    # Plot the TOTAL_FUEL_USED + VALUE_FOB
    ax.plot(flight_data.index, total_fuel_used_plus_fob, label=f'TOTAL_FUEL_USED + VALUE_FOB - Flight {flight}', color='orange')
    
    # Set the title and labels for the subplot
    ax.set_title(f'START_FOB vs (TOTAL_FUEL_USED + VALUE_FOB) for Flight {flight}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Fuel (FOB)')
    
    # Add legend
    ax.legend()
    
    # Show grid
    ax.grid(True)

    # Increment counter
    counter += 1

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
# Select only numeric columns for correlation analysis
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', linewidths=0.5)

# Title
plt.title("Correlation Matrix Heatmap", fontsize=14)
plt.show()

# %%
# Plot scatter plots for key predictors against LEAK_DETECTION_LEAK_FLOW
plt.figure(figsize=(15, 12))

# VALUE_FOB vs LEAK_DETECTION_LEAK_FLOW
plt.subplot(3, 2, 1)
sns.scatterplot(x=df['VALUE_FOB'], y=df['LEAK_DETECTION_LEAK_FLOW'], color='green')
plt.title('VALUE_FOB vs LEAK_DETECTION_LEAK_FLOW')
plt.xlabel('VALUE_FOB')
plt.ylabel('LEAK_DETECTION_LEAK_FLOW')

# 1FOB_DIFFERENCE vs LEAK_DETECTION_LEAK_FLOW (1st equation)
plt.subplot(3, 2, 2)
sns.scatterplot(x=df['1FOB_DIFFERENCE'], y=df['LEAK_DETECTION_LEAK_FLOW'], color='purple')
plt.title('1FOB_DIFFERENCE vs LEAK_DETECTION_LEAK_FLOW')
plt.xlabel('1FOB_DIFFERENCE')
plt.ylabel('LEAK_DETECTION_LEAK_FLOW')

# FOB_DIFFERENCE vs LEAK_DETECTION_LEAK_FLOW (equation 2)
plt.subplot(3, 2, 3)
sns.scatterplot(x=df['FOB_DIFFERENCE'], y=df['LEAK_DETECTION_LEAK_FLOW'], color='blue')
plt.title('FOB_DIFFERENCE vs LEAK_DETECTION_LEAK_FLOW')
plt.xlabel('FOB_DIFFERENCE')
plt.ylabel('LEAK_DETECTION_LEAK_FLOW')

# LW_RW_DIFF vs LEAK_DETECTION_LEAK_FLOW
plt.subplot(3, 2, 4)
sns.boxplot(x=df['LW_RW_DIFF'], y=df['LEAK_DETECTION_LEAK_FLOW'], color='red')
plt.title('LW_RW_DIFF vs LEAK_DETECTION_LEAK_FLOW')
plt.xlabel('LW_RW_DIFF')
plt.ylabel('LEAK_DETECTION_LEAK_FLOW')

# FW_GEO_ALTUTUDE vs LEAK_DETECTION_LEAK_FLOW
plt.subplot(3, 2, 5)
sns.scatterplot(x=df['FW_GEO_ALTITUDE'], y=df['LEAK_DETECTION_LEAK_FLOW'], color='orange')
plt.title('FW_GEO_ALTITUDE vs LEAK_DETECTION_LEAK_FLOW')
plt.xlabel('FW_GEO_ALTITUDE')
plt.ylabel('LEAK_DETECTION_LEAK_FLOW')

plt.tight_layout()
plt.show()
