# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %% [markdown]
# # The dataset

# %%
df = pd.read_csv("combined_simulated.csv")

# %%
# Convert 'UTC_TIME' column to datetime format and sort by time
df['UTC_TIME'] = pd.to_datetime(df['UTC_TIME'])
df.sort_values(by=['FLIGHT_INSTANCE', 'UTC_TIME'], inplace=True)

# %%
# Dropping irrelvant columns
df = df.drop(columns=['FLIGHT_PHASE_COUNT', 'Flight','MSN', 'FLIGHT_INSTANCE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 376554 entries, 0 to 337922
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   UTC_TIME                   376554 non-null  datetime64[ns]
#  1   FUEL_USED_2                376554 non-null  float64
#  2   FUEL_USED_3                376554 non-null  float64
#  3   FUEL_USED_4                376554 non-null  float64
#  4   FW_GEO_ALTITUDE            376554 non-null  float64
#  5   VALUE_FOB                  376554 non-null  float64
#  6   VALUE_FUEL_QTY_CT          376554 non-null  float64
#  7   VALUE_FUEL_QTY_FT1         376554 non-null  float64
#  8   VALUE_FUEL_QTY_FT2         376554 non-null  float64
#  9   VALUE_FUEL_QTY_FT3         376554 non-null  float64
#  10  VALUE_FUEL_QTY_FT4         376554 non-null  float64
#  11  VALUE_FUEL_QTY_LXT         376554 non-null  float64
#  12  VALUE_FUEL_QTY_RXT         376554 non-null  float64
#  13  FUEL_USED_1                376554 non-null  float64
#  14  NEW_FLIGHT                 376554 non-null  bool
#  15  FLIGHT_ID                  376554 non-null  object
#  16  START_FOB                  376554 non-null  float64
#  17  TOTAL_FUEL_USED            376554 non-null  float64
#  18  EXPECTED_FOB               376554 non-null  float64
#  19  FOB_DIFFERENCE             376554 non-null  float64
#  20  FOB_CHANGE                 376554 non-null  float64
#  21  EXPECTED_FOB_CHANGE        376554 non-null  float64
#  22  FUEL_LEAK_RATE             376554 non-null  float64
#  23  TOTAL_FUEL_LW              376554 non-null  float64
#  24  TOTAL_FUEL_RW              376554 non-null  float64
#  25  LW_RW_DIFF                 376554 non-null  float64
#  26  FUEL_IN_TANKS              376554 non-null  float64
#  27  CALC_VALUE_FOB_DIFF        376554 non-null  float64
#  28  START_FOB_VS_FOB_FUELUSED  376554 non-null  float64
#  29  ALTITUDE_DIFF              376554 non-null  float64
#  30  LEAK_FLOW_FLAG             376554 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(27), int64(1), object(1)
# memory usage: 89.4+ MB

# %% [markdown]
# # Modeling

# %%
# 2️⃣ Select all features (except the target)
features = df.columns.tolist()
features.remove('LEAK_FLOW_FLAG')  # Remove target column from features

# Target variable
target = 'LEAK_FLOW_FLAG'

# %%
# Create lag features (memory for time-series)
def create_lag_features(df, features, lags=[1, 3, 5, 10]):
    """
    Adds past values (lags) as new features to help capture time dependency.
    """
    df = df.copy()
    for lag in lags:
        for feature in features:
            df[f'{feature}_lag{lag}'] = df.groupby('FLIGHT_ID')[feature].shift(lag)
    return df

df = create_lag_features(df, features, lags=[1, 3, 5, 10])

# %%
# Drop rows with NaN values (due to lagging)
df.dropna(inplace=True)

# %%
# ROW LEVEL UNDER SAMPLING
# # Keeping 3x as many "No Leak" samples as leak samples
# from sklearn.utils import resample
# # Undersample "No Leak" Cases to Balance the Dataset
# df_leak = df[df["LEAK_FLOW_FLAG"] == 1]
# df_no_leak = df[df["LEAK_FLOW_FLAG"] == 0]

# # Keep 3x as many "No Leak" samples as "Leak" samples
# df_no_leak_balanced = resample(df_no_leak, 
#                                replace=False,  # No replacement (just reducing data)
#                                n_samples=len(df_leak) * 3,  
#                                random_state=42)

# Combine balanced dataset
#df_balanced = pd.concat([df_leak, df_no_leak_balanced])

# %%
# Count leaks per flight
flight_leak_counts = df.groupby("FLIGHT_ID")["LEAK_FLOW_FLAG"].sum()

# ✅ Compute the IQR to find flights with outlier-level leaks
Q1 = flight_leak_counts[flight_leak_counts > 0].quantile(0.25)
Q3 = flight_leak_counts[flight_leak_counts > 0].quantile(0.75)
IQR = Q3 - Q1

# Define outlier threshold (Q3 + 1.5 * IQR)
outlier_threshold = Q3 + (1.5 * IQR)
print(f"Outlier Threshold for Leaks per Flight: {outlier_threshold:.2f}")

# ✅ Select only flights where leaks are higher than the outlier threshold
flights_with_leaks = flight_leak_counts[flight_leak_counts > outlier_threshold].index

# ✅ Reduce No-Leak Flights Even More (1.5x the number of leak flights)
num_leak_flights = len(flights_with_leaks)  # Total number of high-leak flights
num_no_leak_flights = int(num_leak_flights * 1.5)  # Reduce no-leak flights even more

# ✅ Sample only the reduced number of no-leak flights
flights_no_leaks = flight_leak_counts[flight_leak_counts == 0].sample(
    n=num_no_leak_flights, 
    random_state=42
).index

# Keep only selected flights (Preserves sequences!)
df_balanced = df[df["FLIGHT_ID"].isin(flights_with_leaks.union(flights_no_leaks))]
# Out:
# Outlier Threshold for Leaks per Flight: 167.75

# %%
# Keep only selected flights (Preserves sequences!)
df_balanced["LEAK_FLOW_FLAG"].value_counts(normalize=True) * 100
# Out:
# LEAK_FLOW_FLAG
# 0    90.215155
# 1     9.784845
# Name: proportion, dtype: float64

# %%
# 4️⃣ Perform Flight-Level Undersampling to Balance the Dataset

# Count leaks per flight
flight_leak_counts = df.groupby("FLIGHT_ID")["LEAK_FLOW_FLAG"].sum()

# ✅ Compute the IQR to find flights with outlier-level leaks
Q1 = flight_leak_counts[flight_leak_counts > 0].quantile(0.25)
Q3 = flight_leak_counts[flight_leak_counts > 0].quantile(0.75)
IQR = Q3 - Q1

# Define outlier threshold (Q3 + 1.5 * IQR)
outlier_threshold = Q3 + (1.5 * IQR)
print(f"Outlier Threshold for Leaks per Flight: {outlier_threshold:.2f}")

# ✅ Select only flights where leaks are higher than the outlier threshold
flights_with_leaks = flight_leak_counts[flight_leak_counts > outlier_threshold].index

# ✅ Further Reduce No-Leak Flights (Now 1.2x instead of 1.5x)
num_leak_flights = len(flights_with_leaks)  # Total number of high-leak flights
num_no_leak_flights = int(num_leak_flights * 1.2)  # Reduce no-leak flights even more

# ✅ Sample only the reduced number of no-leak flights
flights_no_leaks = flight_leak_counts[flight_leak_counts == 0].sample(
    n=num_no_leak_flights, 
    random_state=42
).index

# Keep only selected flights (Preserves sequences!)
df_balanced = df[df["FLIGHT_ID"].isin(flights_with_leaks.union(flights_no_leaks))]
# Out:
# Outlier Threshold for Leaks per Flight: 167.75

# %%
# Keep only selected flights (Preserves sequences!)
df_balanced["LEAK_FLOW_FLAG"].value_counts(normalize=True) * 100
# Out:
# LEAK_FLOW_FLAG
# 0    89.997596
# 1    10.002404
# Name: proportion, dtype: float64

# %%
# 4️⃣ Perform Flight-Level Undersampling to Balance the Dataset

# Count leaks per flight
flight_leak_counts = df.groupby("FLIGHT_ID")["LEAK_FLOW_FLAG"].sum()

# ✅ Compute the IQR to find flights with outlier-level leaks
Q1 = flight_leak_counts[flight_leak_counts > 0].quantile(0.25)
Q3 = flight_leak_counts[flight_leak_counts > 0].quantile(0.75)
IQR = Q3 - Q1

# Define outlier threshold (Q3 + 1.5 * IQR)
outlier_threshold = Q3 + (1.5 * IQR)
print(f"Outlier Threshold for Leaks per Flight: {outlier_threshold:.2f}")

# ✅ Select only flights where leaks are higher than the outlier threshold
flights_with_leaks = flight_leak_counts[flight_leak_counts > outlier_threshold].index

# ✅ Aggressively Reduce No-Leak Flights (Now 1.0x instead of 1.2x)
num_leak_flights = len(flights_with_leaks)  # Total number of high-leak flights
num_no_leak_flights = int(num_leak_flights * 1.0)  # Keep only as many no-leak flights as leak flights

# ✅ Sample only the reduced number of no-leak flights
flights_no_leaks = flight_leak_counts[flight_leak_counts == 0].sample(
    n=num_no_leak_flights, 
    random_state=42
).index

# Keep only selected flights (Preserves sequences!)
df_balanced = df[df["FLIGHT_ID"].isin(flights_with_leaks.union(flights_no_leaks))]
# Out:
# Outlier Threshold for Leaks per Flight: 167.75

# %%
# Keep only selected flights (Preserves sequences!)
df_balanced["LEAK_FLOW_FLAG"].value_counts(normalize=True) * 100
# Out:
# LEAK_FLOW_FLAG
# 0    89.931648
# 1    10.068352
# Name: proportion, dtype: float64

# %%
# Count leaks per flight
flight_leak_counts = df.groupby("FLIGHT_ID")["LEAK_FLOW_FLAG"].sum()

# ✅ Compute the IQR to find flights with outlier-level leaks
Q1 = flight_leak_counts[flight_leak_counts > 0].quantile(0.25)
Q3 = flight_leak_counts[flight_leak_counts > 0].quantile(0.75)
IQR = Q3 - Q1

# Define outlier threshold (Q3 + 1.5 * IQR)
outlier_threshold = Q3 + (1.5 * IQR)
print(f"Outlier Threshold for Leaks per Flight: {outlier_threshold:.2f}")

# ✅ Select only flights where leaks are higher than the outlier threshold
flights_with_leaks = flight_leak_counts[flight_leak_counts > outlier_threshold].index

# ✅ EXTREME Reduction: Only keep 0.5x as many no-leak flights as leak flights
num_leak_flights = len(flights_with_leaks)  # Total number of high-leak flights
num_no_leak_flights = int(num_leak_flights * 0.01)  # Cut down no-leak flights aggressively

# ✅ Sample only the reduced number of no-leak flights
flights_no_leaks = flight_leak_counts[flight_leak_counts == 0].sample(
    n=num_no_leak_flights, 
    random_state=42
).index

# Keep only selected flights (Preserves sequences!)
df_balanced = df[df["FLIGHT_ID"].isin(flights_with_leaks.union(flights_no_leaks))]
# Out:
# Outlier Threshold for Leaks per Flight: 167.75

# %%
# Keep only selected flights (Preserves sequences!)
df_balanced["LEAK_FLOW_FLAG"].value_counts(normalize=True) * 100
# Out:
# LEAK_FLOW_FLAG
# 0    86.996602
# 1    13.003398
# Name: proportion, dtype: float64

# %%
# Count leaks per flight
flight_leak_counts = df.groupby("FLIGHT_ID")["LEAK_FLOW_FLAG"].sum()

# ✅ Compute the Mean Number of Leaks per Flight
mean_leaks_per_flight = flight_leak_counts[flight_leak_counts > 0].median()
print(f"Mean Number of Leaks per Flight: {mean_leaks_per_flight:.2f}")

# ✅ Select flights where the number of leaks is higher than the mean
flights_with_leaks = flight_leak_counts[flight_leak_counts > mean_leaks_per_flight].index

# ✅ EXTREME Reduction: Only keep 0.5x as many no-leak flights as leak flights
num_leak_flights = len(flights_with_leaks)  # Total number of high-leak flights
num_no_leak_flights = int(num_leak_flights * 0.01)  # Cut down no-leak flights aggressively

# ✅ Sample only the reduced number of no-leak flights
flights_no_leaks = flight_leak_counts[flight_leak_counts == 0].sample(
    n=num_no_leak_flights, 
    random_state=42
).index

# Keep only selected flights (Preserves sequences!)
df_balanced = df[df["FLIGHT_ID"].isin(flights_with_leaks.union(flights_no_leaks))]
# Out:
# Mean Number of Leaks per Flight: 33.00

# %%
# Keep only selected flights (Preserves sequences!)
df_balanced["LEAK_FLOW_FLAG"].value_counts(normalize=True) * 100
# Out:
# LEAK_FLOW_FLAG
# 0    88.509981
# 1    11.490019
# Name: proportion, dtype: float64

# %%
# Count leaks per flight
flight_leak_counts = df.groupby("FLIGHT_ID")["LEAK_FLOW_FLAG"].sum()

# ✅ Compute the Mean Number of Leaks per Flight
mean_leaks_per_flight = flight_leak_counts[flight_leak_counts > 0].mean()
print(f"Mean Number of Leaks per Flight: {mean_leaks_per_flight:.2f}")

# ✅ Select flights where the number of leaks is higher than the median
flights_with_leaks = flight_leak_counts[flight_leak_counts > mean_leaks_per_flight].index

# ✅ EXTREME Reduction: Only keep 1% as many no-leak flights as leak flights
num_leak_flights = len(flights_with_leaks)  # Total number of flights with leaks
num_no_leak_flights = int(num_leak_flights * 0.01)  # Cut down no-leak flights aggressively

# ✅ Sample only the reduced number of no-leak flights
flights_no_leaks = flight_leak_counts[flight_leak_counts == 0].sample(
    n=num_no_leak_flights, 
    random_state=42
).index

# Keep only selected flights (Preserves sequences!)
df_balanced = df[df["FLIGHT_ID"].isin(flights_with_leaks.union(flights_no_leaks))]
# Out:
# Mean Number of Leaks per Flight: 66.87

# %%
# Keep only selected flights (Preserves sequences!)
df_balanced["LEAK_FLOW_FLAG"].value_counts(normalize=True) * 100
# Out:
# LEAK_FLOW_FLAG
# 0    85.797351
# 1    14.202649
# Name: proportion, dtype: float64

# %%
df_balanced.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35944 entries, 19979 to 345135
# Data columns (total 631 columns):
#  #    Column                                 Non-Null Count  Dtype
# ---   ------                                 --------------  -----
#  0    UTC_TIME                               35944 non-null  datetime64[ns]
#  1    FUEL_USED_2                            35944 non-null  float64
#  2    FUEL_USED_3                            35944 non-null  float64
#  3    FUEL_USED_4                            35944 non-null  float64
#  4    FW_GEO_ALTITUDE                        35944 non-null  float64
#  5    VALUE_FOB                              35944 non-null  float64
#  6    VALUE_FUEL_QTY_CT                      35944 non-null  float64
#  7    VALUE_FUEL_QTY_FT1                     35944 non-null  float64
#  8    VALUE_FUEL_QTY_FT2                     35944 non-null  float64
#  9    VALUE_FUEL_QTY_FT3                     35944 non-null  float64
#  10   VALUE_FUEL_QTY_FT4                     35944 non-null  float64
#  11   VALUE_FUEL_QTY_LXT                     35944 non-null  float64
#  12   VALUE_FUEL_QTY_RXT                     35944 non-null  float64
#  13   FUEL_USED_1                            35944 non-null  float64
#  14   NEW_FLIGHT                             35944 non-null  bool
#  15   FLIGHT_ID                              35944 non-null  object
#  16   START_FOB                              35944 non-null  float64
#  17   TOTAL_FUEL_USED                        35944 non-null  float64
#  18   EXPECTED_FOB                           35944 non-null  float64
#  19   FOB_DIFFERENCE                         35944 non-null  float64
#  20   FOB_CHANGE                             35944 non-null  float64
#  21   EXPECTED_FOB_CHANGE                    35944 non-null  float64
#  22   FUEL_LEAK_RATE                         35944 non-null  float64
#  23   TOTAL_FUEL_LW                          35944 non-null  float64
#  24   TOTAL_FUEL_RW                          35944 non-null  float64
#  25   LW_RW_DIFF                             35944 non-null  float64
#  26   FUEL_IN_TANKS                          35944 non-null  float64
#  27   CALC_VALUE_FOB_DIFF                    35944 non-null  float64
#  28   START_FOB_VS_FOB_FUELUSED              35944 non-null  float64
#  29   ALTITUDE_DIFF                          35944 non-null  float64
#  30   LEAK_FLOW_FLAG                         35944 non-null  int64
#  31   UTC_TIME_lag1                          35944 non-null  datetime64[ns]
#  32   FUEL_USED_2_lag1                       35944 non-null  float64
#  33   FUEL_USED_3_lag1                       35944 non-null  float64
#  34   FUEL_USED_4_lag1                       35944 non-null  float64
#  35   FW_GEO_ALTITUDE_lag1                   35944 non-null  float64
#  36   VALUE_FOB_lag1                         35944 non-null  float64
#  37   VALUE_FUEL_QTY_CT_lag1                 35944 non-null  float64
#  38   VALUE_FUEL_QTY_FT1_lag1                35944 non-null  float64
#  39   VALUE_FUEL_QTY_FT2_lag1                35944 non-null  float64
#  40   VALUE_FUEL_QTY_FT3_lag1                35944 non-null  float64
#  41   VALUE_FUEL_QTY_FT4_lag1                35944 non-null  float64
#  42   VALUE_FUEL_QTY_LXT_lag1                35944 non-null  float64
#  43   VALUE_FUEL_QTY_RXT_lag1                35944 non-null  float64
#  44   FUEL_USED_1_lag1                       35944 non-null  float64
#  45   NEW_FLIGHT_lag1                        35944 non-null  object
#  46   FLIGHT_ID_lag1                         35944 non-null  object
#  47   START_FOB_lag1                         35944 non-null  float64
#  48   TOTAL_FUEL_USED_lag1                   35944 non-null  float64
#  49   EXPECTED_FOB_lag1                      35944 non-null  float64
#  50   FOB_DIFFERENCE_lag1                    35944 non-null  float64
#  51   FOB_CHANGE_lag1                        35944 non-null  float64
#  52   EXPECTED_FOB_CHANGE_lag1               35944 non-null  float64
#  53   FUEL_LEAK_RATE_lag1                    35944 non-null  float64
#  54   TOTAL_FUEL_LW_lag1                     35944 non-null  float64
#  55   TOTAL_FUEL_RW_lag1                     35944 non-null  float64
#  56   LW_RW_DIFF_lag1                        35944 non-null  float64
#  57   FUEL_IN_TANKS_lag1                     35944 non-null  float64
#  58   CALC_VALUE_FOB_DIFF_lag1               35944 non-null  float64
#  59   START_FOB_VS_FOB_FUELUSED_lag1         35944 non-null  float64
#  60   ALTITUDE_DIFF_lag1                     35944 non-null  float64
#  61   UTC_TIME_lag3                          35944 non-null  datetime64[ns]
#  62   FUEL_USED_2_lag3                       35944 non-null  float64
#  63   FUEL_USED_3_lag3                       35944 non-null  float64
#  64   FUEL_USED_4_lag3                       35944 non-null  float64
#  65   FW_GEO_ALTITUDE_lag3                   35944 non-null  float64
#  66   VALUE_FOB_lag3                         35944 non-null  float64
#  67   VALUE_FUEL_QTY_CT_lag3                 35944 non-null  float64
#  68   VALUE_FUEL_QTY_FT1_lag3                35944 non-null  float64
#  69   VALUE_FUEL_QTY_FT2_lag3                35944 non-null  float64
#  70   VALUE_FUEL_QTY_FT3_lag3                35944 non-null  float64
#  71   VALUE_FUEL_QTY_FT4_lag3                35944 non-null  float64
#  72   VALUE_FUEL_QTY_LXT_lag3                35944 non-null  float64
#  73   VALUE_FUEL_QTY_RXT_lag3                35944 non-null  float64
#  74   FUEL_USED_1_lag3                       35944 non-null  float64
#  75   NEW_FLIGHT_lag3                        35944 non-null  object
#  76   FLIGHT_ID_lag3                         35944 non-null  object
#  77   START_FOB_lag3                         35944 non-null  float64
#  78   TOTAL_FUEL_USED_lag3                   35944 non-null  float64
#  79   EXPECTED_FOB_lag3                      35944 non-null  float64
#  80   FOB_DIFFERENCE_lag3                    35944 non-null  float64
#  81   FOB_CHANGE_lag3                        35944 non-null  float64
#  82   EXPECTED_FOB_CHANGE_lag3               35944 non-null  float64
#  83   FUEL_LEAK_RATE_lag3                    35944 non-null  float64
#  84   TOTAL_FUEL_LW_lag3                     35944 non-null  float64
#  85   TOTAL_FUEL_RW_lag3                     35944 non-null  float64
#  86   LW_RW_DIFF_lag3                        35944 non-null  float64
#  87   FUEL_IN_TANKS_lag3                     35944 non-null  float64
#  88   CALC_VALUE_FOB_DIFF_lag3               35944 non-null  float64
#  89   START_FOB_VS_FOB_FUELUSED_lag3         35944 non-null  float64
#  90   ALTITUDE_DIFF_lag3                     35944 non-null  float64
#  91   UTC_TIME_lag5                          35944 non-null  datetime64[ns]
#  92   FUEL_USED_2_lag5                       35944 non-null  float64
#  93   FUEL_USED_3_lag5                       35944 non-null  float64
#  94   FUEL_USED_4_lag5                       35944 non-null  float64
#  95   FW_GEO_ALTITUDE_lag5                   35944 non-null  float64
#  96   VALUE_FOB_lag5                         35944 non-null  float64
#  97   VALUE_FUEL_QTY_CT_lag5                 35944 non-null  float64
#  98   VALUE_FUEL_QTY_FT1_lag5                35944 non-null  float64
#  99   VALUE_FUEL_QTY_FT2_lag5                35944 non-null  float64
#  100  VALUE_FUEL_QTY_FT3_lag5                35944 non-null  float64
#  101  VALUE_FUEL_QTY_FT4_lag5                35944 non-null  float64
#  102  VALUE_FUEL_QTY_LXT_lag5                35944 non-null  float64
#  103  VALUE_FUEL_QTY_RXT_lag5                35944 non-null  float64
#  104  FUEL_USED_1_lag5                       35944 non-null  float64
#  105  NEW_FLIGHT_lag5                        35944 non-null  object
#  106  FLIGHT_ID_lag5                         35944 non-null  object
#  107  START_FOB_lag5                         35944 non-null  float64
#  108  TOTAL_FUEL_USED_lag5                   35944 non-null  float64
#  109  EXPECTED_FOB_lag5                      35944 non-null  float64
#  110  FOB_DIFFERENCE_lag5                    35944 non-null  float64
#  111  FOB_CHANGE_lag5                        35944 non-null  float64
#  112  EXPECTED_FOB_CHANGE_lag5               35944 non-null  float64
#  113  FUEL_LEAK_RATE_lag5                    35944 non-null  float64
#  114  TOTAL_FUEL_LW_lag5                     35944 non-null  float64
#  115  TOTAL_FUEL_RW_lag5                     35944 non-null  float64
#  116  LW_RW_DIFF_lag5                        35944 non-null  float64
#  117  FUEL_IN_TANKS_lag5                     35944 non-null  float64
#  118  CALC_VALUE_FOB_DIFF_lag5               35944 non-null  float64
#  119  START_FOB_VS_FOB_FUELUSED_lag5         35944 non-null  float64
#  120  ALTITUDE_DIFF_lag5                     35944 non-null  float64
#  121  UTC_TIME_lag10                         35944 non-null  datetime64[ns]
#  122  FUEL_USED_2_lag10                      35944 non-null  float64
#  123  FUEL_USED_3_lag10                      35944 non-null  float64
#  124  FUEL_USED_4_lag10                      35944 non-null  float64
#  125  FW_GEO_ALTITUDE_lag10                  35944 non-null  float64
#  126  VALUE_FOB_lag10                        35944 non-null  float64
#  127  VALUE_FUEL_QTY_CT_lag10                35944 non-null  float64
#  128  VALUE_FUEL_QTY_FT1_lag10               35944 non-null  float64
#  129  VALUE_FUEL_QTY_FT2_lag10               35944 non-null  float64
#  130  VALUE_FUEL_QTY_FT3_lag10               35944 non-null  float64
#  131  VALUE_FUEL_QTY_FT4_lag10               35944 non-null  float64
#  132  VALUE_FUEL_QTY_LXT_lag10               35944 non-null  float64
#  133  VALUE_FUEL_QTY_RXT_lag10               35944 non-null  float64
#  134  FUEL_USED_1_lag10                      35944 non-null  float64
#  135  NEW_FLIGHT_lag10                       35944 non-null  object
#  136  FLIGHT_ID_lag10                        35944 non-null  object
#  137  START_FOB_lag10                        35944 non-null  float64
#  138  TOTAL_FUEL_USED_lag10                  35944 non-null  float64
#  139  EXPECTED_FOB_lag10                     35944 non-null  float64
#  140  FOB_DIFFERENCE_lag10                   35944 non-null  float64
#  141  FOB_CHANGE_lag10                       35944 non-null  float64
#  142  EXPECTED_FOB_CHANGE_lag10              35944 non-null  float64
#  143  FUEL_LEAK_RATE_lag10                   35944 non-null  float64
#  144  TOTAL_FUEL_LW_lag10                    35944 non-null  float64
#  145  TOTAL_FUEL_RW_lag10                    35944 non-null  float64
#  146  LW_RW_DIFF_lag10                       35944 non-null  float64
#  147  FUEL_IN_TANKS_lag10                    35944 non-null  float64
#  148  CALC_VALUE_FOB_DIFF_lag10              35944 non-null  float64
#  192  VALUE_FUEL_QTY_LXT_lag3_lag1           35944 non-null  float64
#  193  VALUE_FUEL_QTY_RXT_lag3_lag1           35944 non-null  float64
#  194  FUEL_USED_1_lag3_lag1                  35944 non-null  float64
#  195  NEW_FLIGHT_lag3_lag1                   35944 non-null  object
#  196  FLIGHT_ID_lag3_lag1                    35944 non-null  object
#  197  START_FOB_lag3_lag1                    35944 non-null  float64
#  198  TOTAL_FUEL_USED_lag3_lag1              35944 non-null  float64
#  199  EXPECTED_FOB_lag3_lag1                 35944 non-null  float64
#  200  FOB_DIFFERENCE_lag3_lag1               35944 non-null  float64
#  201  FOB_CHANGE_lag3_lag1                   35944 non-null  float64
#  202  EXPECTED_FOB_CHANGE_lag3_lag1          35944 non-null  float64
#  203  FUEL_LEAK_RATE_lag3_lag1               35944 non-null  float64
#  204  TOTAL_FUEL_LW_lag3_lag1                35944 non-null  float64
#  205  TOTAL_FUEL_RW_lag3_lag1                35944 non-null  float64
#  206  LW_RW_DIFF_lag3_lag1                   35944 non-null  float64
#  207  FUEL_IN_TANKS_lag3_lag1                35944 non-null  float64
#  208  CALC_VALUE_FOB_DIFF_lag3_lag1          35944 non-null  float64
#  209  START_FOB_VS_FOB_FUELUSED_lag3_lag1    35944 non-null  float64
#  210  ALTITUDE_DIFF_lag3_lag1                35944 non-null  float64
#  211  UTC_TIME_lag5_lag1                     35944 non-null  datetime64[ns]
#  212  FUEL_USED_2_lag5_lag1                  35944 non-null  float64
#  213  FUEL_USED_3_lag5_lag1                  35944 non-null  float64
#  214  FUEL_USED_4_lag5_lag1                  35944 non-null  float64
#  215  FW_GEO_ALTITUDE_lag5_lag1              35944 non-null  float64
#  216  VALUE_FOB_lag5_lag1                    35944 non-null  float64
#  217  VALUE_FUEL_QTY_CT_lag5_lag1            35944 non-null  float64
#  218  VALUE_FUEL_QTY_FT1_lag5_lag1           35944 non-null  float64
#  219  VALUE_FUEL_QTY_FT2_lag5_lag1           35944 non-null  float64
#  220  VALUE_FUEL_QTY_FT3_lag5_lag1           35944 non-null  float64
#  221  VALUE_FUEL_QTY_FT4_lag5_lag1           35944 non-null  float64
#  222  VALUE_FUEL_QTY_LXT_lag5_lag1           35944 non-null  float64
#  223  VALUE_FUEL_QTY_RXT_lag5_lag1           35944 non-null  float64
#  224  FUEL_USED_1_lag5_lag1                  35944 non-null  float64
#  225  NEW_FLIGHT_lag5_lag1                   35944 non-null  object
#  226  FLIGHT_ID_lag5_lag1                    35944 non-null  object
#  227  START_FOB_lag5_lag1                    35944 non-null  float64
#  228  TOTAL_FUEL_USED_lag5_lag1              35944 non-null  float64
#  229  EXPECTED_FOB_lag5_lag1                 35944 non-null  float64
#  230  FOB_DIFFERENCE_lag5_lag1               35944 non-null  float64
#  231  FOB_CHANGE_lag5_lag1                   35944 non-null  float64
#  232  EXPECTED_FOB_CHANGE_lag5_lag1          35944 non-null  float64
#  233  FUEL_LEAK_RATE_lag5_lag1               35944 non-null  float64
#  234  TOTAL_FUEL_LW_lag5_lag1                35944 non-null  float64
#  235  TOTAL_FUEL_RW_lag5_lag1                35944 non-null  float64
#  236  LW_RW_DIFF_lag5_lag1                   35944 non-null  float64
#  237  FUEL_IN_TANKS_lag5_lag1                35944 non-null  float64
#  238  CALC_VALUE_FOB_DIFF_lag5_lag1          35944 non-null  float64
#  239  START_FOB_VS_FOB_FUELUSED_lag5_lag1    35944 non-null  float64
#  240  ALTITUDE_DIFF_lag5_lag1                35944 non-null  float64
#  241  UTC_TIME_lag10_lag1                    35944 non-null  datetime64[ns]
#  242  FUEL_USED_2_lag10_lag1                 35944 non-null  float64
#  243  FUEL_USED_3_lag10_lag1                 35944 non-null  float64
#  244  FUEL_USED_4_lag10_lag1                 35944 non-null  float64
#  245  FW_GEO_ALTITUDE_lag10_lag1             35944 non-null  float64
#  246  VALUE_FOB_lag10_lag1                   35944 non-null  float64
#  247  VALUE_FUEL_QTY_CT_lag10_lag1           35944 non-null  float64
#  248  VALUE_FUEL_QTY_FT1_lag10_lag1          35944 non-null  float64
#  249  VALUE_FUEL_QTY_FT2_lag10_lag1          35944 non-null  float64
#  250  VALUE_FUEL_QTY_FT3_lag10_lag1          35944 non-null  float64
#  251  VALUE_FUEL_QTY_FT4_lag10_lag1          35944 non-null  float64
#  252  VALUE_FUEL_QTY_LXT_lag10_lag1          35944 non-null  float64
#  253  VALUE_FUEL_QTY_RXT_lag10_lag1          35944 non-null  float64
#  254  FUEL_USED_1_lag10_lag1                 35944 non-null  float64
#  255  NEW_FLIGHT_lag10_lag1                  35944 non-null  object
#  256  FLIGHT_ID_lag10_lag1                   35944 non-null  object
#  257  START_FOB_lag10_lag1                   35944 non-null  float64
#  258  TOTAL_FUEL_USED_lag10_lag1             35944 non-null  float64
#  259  EXPECTED_FOB_lag10_lag1                35944 non-null  float64
#  260  FOB_DIFFERENCE_lag10_lag1              35944 non-null  float64
#  261  FOB_CHANGE_lag10_lag1                  35944 non-null  float64
#  262  EXPECTED_FOB_CHANGE_lag10_lag1         35944 non-null  float64
#  263  FUEL_LEAK_RATE_lag10_lag1              35944 non-null  float64
#  264  TOTAL_FUEL_LW_lag10_lag1               35944 non-null  float64
#  265  TOTAL_FUEL_RW_lag10_lag1               35944 non-null  float64
#  266  LW_RW_DIFF_lag10_lag1                  35944 non-null  float64
#  267  FUEL_IN_TANKS_lag10_lag1               35944 non-null  float64
#  268  CALC_VALUE_FOB_DIFF_lag10_lag1         35944 non-null  float64
#  269  START_FOB_VS_FOB_FUELUSED_lag10_lag1   35944 non-null  float64
#  270  ALTITUDE_DIFF_lag10_lag1               35944 non-null  float64
#  271  UTC_TIME_lag1_lag3                     35944 non-null  datetime64[ns]
#  272  FUEL_USED_2_lag1_lag3                  35944 non-null  float64
#  273  FUEL_USED_3_lag1_lag3                  35944 non-null  float64
#  274  FUEL_USED_4_lag1_lag3                  35944 non-null  float64
#  275  FW_GEO_ALTITUDE_lag1_lag3              35944 non-null  float64
#  276  VALUE_FOB_lag1_lag3                    35944 non-null  float64
#  320  FOB_DIFFERENCE_lag3_lag3               35944 non-null  float64
#  321  FOB_CHANGE_lag3_lag3                   35944 non-null  float64
#  322  EXPECTED_FOB_CHANGE_lag3_lag3          35944 non-null  float64
#  323  FUEL_LEAK_RATE_lag3_lag3               35944 non-null  float64
#  324  TOTAL_FUEL_LW_lag3_lag3                35944 non-null  float64
#  325  TOTAL_FUEL_RW_lag3_lag3                35944 non-null  float64
#  326  LW_RW_DIFF_lag3_lag3                   35944 non-null  float64
#  327  FUEL_IN_TANKS_lag3_lag3                35944 non-null  float64
#  328  CALC_VALUE_FOB_DIFF_lag3_lag3          35944 non-null  float64
#  329  START_FOB_VS_FOB_FUELUSED_lag3_lag3    35944 non-null  float64
#  330  ALTITUDE_DIFF_lag3_lag3                35944 non-null  float64
#  331  UTC_TIME_lag5_lag3                     35944 non-null  datetime64[ns]
#  332  FUEL_USED_2_lag5_lag3                  35944 non-null  float64
#  333  FUEL_USED_3_lag5_lag3                  35944 non-null  float64
#  334  FUEL_USED_4_lag5_lag3                  35944 non-null  float64
#  335  FW_GEO_ALTITUDE_lag5_lag3              35944 non-null  float64
#  336  VALUE_FOB_lag5_lag3                    35944 non-null  float64
#  337  VALUE_FUEL_QTY_CT_lag5_lag3            35944 non-null  float64
#  338  VALUE_FUEL_QTY_FT1_lag5_lag3           35944 non-null  float64
#  339  VALUE_FUEL_QTY_FT2_lag5_lag3           35944 non-null  float64
#  340  VALUE_FUEL_QTY_FT3_lag5_lag3           35944 non-null  float64
#  341  VALUE_FUEL_QTY_FT4_lag5_lag3           35944 non-null  float64
#  342  VALUE_FUEL_QTY_LXT_lag5_lag3           35944 non-null  float64
#  343  VALUE_FUEL_QTY_RXT_lag5_lag3           35944 non-null  float64
#  344  FUEL_USED_1_lag5_lag3                  35944 non-null  float64
#  345  NEW_FLIGHT_lag5_lag3                   35944 non-null  object
#  346  FLIGHT_ID_lag5_lag3                    35944 non-null  object
#  347  START_FOB_lag5_lag3                    35944 non-null  float64
#  348  TOTAL_FUEL_USED_lag5_lag3              35944 non-null  float64
#  349  EXPECTED_FOB_lag5_lag3                 35944 non-null  float64
#  350  FOB_DIFFERENCE_lag5_lag3               35944 non-null  float64
#  351  FOB_CHANGE_lag5_lag3                   35944 non-null  float64
#  352  EXPECTED_FOB_CHANGE_lag5_lag3          35944 non-null  float64
#  353  FUEL_LEAK_RATE_lag5_lag3               35944 non-null  float64
#  354  TOTAL_FUEL_LW_lag5_lag3                35944 non-null  float64
#  355  TOTAL_FUEL_RW_lag5_lag3                35944 non-null  float64
#  356  LW_RW_DIFF_lag5_lag3                   35944 non-null  float64
#  357  FUEL_IN_TANKS_lag5_lag3                35944 non-null  float64
#  358  CALC_VALUE_FOB_DIFF_lag5_lag3          35944 non-null  float64
#  359  START_FOB_VS_FOB_FUELUSED_lag5_lag3    35944 non-null  float64
#  360  ALTITUDE_DIFF_lag5_lag3                35944 non-null  float64
#  361  UTC_TIME_lag10_lag3                    35944 non-null  datetime64[ns]
#  405  NEW_FLIGHT_lag1_lag5                   35944 non-null  object
#  406  FLIGHT_ID_lag1_lag5                    35944 non-null  object
#  407  START_FOB_lag1_lag5                    35944 non-null  float64
#  408  TOTAL_FUEL_USED_lag1_lag5              35944 non-null  float64
#  409  EXPECTED_FOB_lag1_lag5                 35944 non-null  float64
#  410  FOB_DIFFERENCE_lag1_lag5               35944 non-null  float64
#  411  FOB_CHANGE_lag1_lag5                   35944 non-null  float64
#  412  EXPECTED_FOB_CHANGE_lag1_lag5          35944 non-null  float64
#  413  FUEL_LEAK_RATE_lag1_lag5               35944 non-null  float64
#  414  TOTAL_FUEL_LW_lag1_lag5                35944 non-null  float64
#  415  TOTAL_FUEL_RW_lag1_lag5                35944 non-null  float64
#  416  LW_RW_DIFF_lag1_lag5                   35944 non-null  float64
#  417  FUEL_IN_TANKS_lag1_lag5                35944 non-null  float64
#  418  CALC_VALUE_FOB_DIFF_lag1_lag5          35944 non-null  float64
#  419  START_FOB_VS_FOB_FUELUSED_lag1_lag5    35944 non-null  float64
#  420  ALTITUDE_DIFF_lag1_lag5                35944 non-null  float64
#  421  UTC_TIME_lag3_lag5                     35944 non-null  datetime64[ns]
#  422  FUEL_USED_2_lag3_lag5                  35944 non-null  float64
#  423  FUEL_USED_3_lag3_lag5                  35944 non-null  float64
#  424  FUEL_USED_4_lag3_lag5                  35944 non-null  float64
#  425  FW_GEO_ALTITUDE_lag3_lag5              35944 non-null  float64
#  426  VALUE_FOB_lag3_lag5                    35944 non-null  float64
#  427  VALUE_FUEL_QTY_CT_lag3_lag5            35944 non-null  float64
#  428  VALUE_FUEL_QTY_FT1_lag3_lag5           35944 non-null  float64
#  429  VALUE_FUEL_QTY_FT2_lag3_lag5           35944 non-null  float64
#  430  VALUE_FUEL_QTY_FT3_lag3_lag5           35944 non-null  float64
#  431  VALUE_FUEL_QTY_FT4_lag3_lag5           35944 non-null  float64
#  432  VALUE_FUEL_QTY_LXT_lag3_lag5           35944 non-null  float64
#  433  VALUE_FUEL_QTY_RXT_lag3_lag5           35944 non-null  float64
#  434  FUEL_USED_1_lag3_lag5                  35944 non-null  float64
#  435  NEW_FLIGHT_lag3_lag5                   35944 non-null  object
#  436  FLIGHT_ID_lag3_lag5                    35944 non-null  object
#  437  START_FOB_lag3_lag5                    35944 non-null  float64
#  438  TOTAL_FUEL_USED_lag3_lag5              35944 non-null  float64
#  439  EXPECTED_FOB_lag3_lag5                 35944 non-null  float64
#  440  FOB_DIFFERENCE_lag3_lag5               35944 non-null  float64
#  441  FOB_CHANGE_lag3_lag5                   35944 non-null  float64
#  442  EXPECTED_FOB_CHANGE_lag3_lag5          35944 non-null  float64
#  443  FUEL_LEAK_RATE_lag3_lag5               35944 non-null  float64
#  444  TOTAL_FUEL_LW_lag3_lag5                35944 non-null  float64
#  445  TOTAL_FUEL_RW_lag3_lag5                35944 non-null  float64
#  446  LW_RW_DIFF_lag3_lag5                   35944 non-null  float64
#  447  FUEL_IN_TANKS_lag3_lag5                35944 non-null  float64
#  448  CALC_VALUE_FOB_DIFF_lag3_lag5          35944 non-null  float64
#  449  START_FOB_VS_FOB_FUELUSED_lag3_lag5    35944 non-null  float64
#  450  ALTITUDE_DIFF_lag3_lag5                35944 non-null  float64
#  451  UTC_TIME_lag5_lag5                     35944 non-null  datetime64[ns]
#  452  FUEL_USED_2_lag5_lag5                  35944 non-null  float64
#  453  FUEL_USED_3_lag5_lag5                  35944 non-null  float64
#  454  FUEL_USED_4_lag5_lag5                  35944 non-null  float64
#  455  FW_GEO_ALTITUDE_lag5_lag5              35944 non-null  float64
#  456  VALUE_FOB_lag5_lag5                    35944 non-null  float64
#  457  VALUE_FUEL_QTY_CT_lag5_lag5            35944 non-null  float64
#  458  VALUE_FUEL_QTY_FT1_lag5_lag5           35944 non-null  float64
#  459  VALUE_FUEL_QTY_FT2_lag5_lag5           35944 non-null  float64
#  460  VALUE_FUEL_QTY_FT3_lag5_lag5           35944 non-null  float64
#  461  VALUE_FUEL_QTY_FT4_lag5_lag5           35944 non-null  float64
#  462  VALUE_FUEL_QTY_LXT_lag5_lag5           35944 non-null  float64
#  463  VALUE_FUEL_QTY_RXT_lag5_lag5           35944 non-null  float64
#  464  FUEL_USED_1_lag5_lag5                  35944 non-null  float64
#  465  NEW_FLIGHT_lag5_lag5                   35944 non-null  object
#  466  FLIGHT_ID_lag5_lag5                    35944 non-null  object
#  467  START_FOB_lag5_lag5                    35944 non-null  float64
#  468  TOTAL_FUEL_USED_lag5_lag5              35944 non-null  float64
#  469  EXPECTED_FOB_lag5_lag5                 35944 non-null  float64
#  470  FOB_DIFFERENCE_lag5_lag5               35944 non-null  float64
#  471  FOB_CHANGE_lag5_lag5                   35944 non-null  float64
#  472  EXPECTED_FOB_CHANGE_lag5_lag5          35944 non-null  float64
#  473  FUEL_LEAK_RATE_lag5_lag5               35944 non-null  float64
#  474  TOTAL_FUEL_LW_lag5_lag5                35944 non-null  float64
#  475  TOTAL_FUEL_RW_lag5_lag5                35944 non-null  float64
#  476  LW_RW_DIFF_lag5_lag5                   35944 non-null  float64
#  477  FUEL_IN_TANKS_lag5_lag5                35944 non-null  float64
#  478  CALC_VALUE_FOB_DIFF_lag5_lag5          35944 non-null  float64
#  479  START_FOB_VS_FOB_FUELUSED_lag5_lag5    35944 non-null  float64
#  480  ALTITUDE_DIFF_lag5_lag5                35944 non-null  float64
#  481  UTC_TIME_lag10_lag5                    35944 non-null  datetime64[ns]
#  482  FUEL_USED_2_lag10_lag5                 35944 non-null  float64
#  483  FUEL_USED_3_lag10_lag5                 35944 non-null  float64
#  484  FUEL_USED_4_lag10_lag5                 35944 non-null  float64
#  485  FW_GEO_ALTITUDE_lag10_lag5             35944 non-null  float64
#  486  VALUE_FOB_lag10_lag5                   35944 non-null  float64
#  487  VALUE_FUEL_QTY_CT_lag10_lag5           35944 non-null  float64
#  488  VALUE_FUEL_QTY_FT1_lag10_lag5          35944 non-null  float64
#  489  VALUE_FUEL_QTY_FT2_lag10_lag5          35944 non-null  float64
#  490  VALUE_FUEL_QTY_FT3_lag10_lag5          35944 non-null  float64
#  491  VALUE_FUEL_QTY_FT4_lag10_lag5          35944 non-null  float64
#  492  VALUE_FUEL_QTY_LXT_lag10_lag5          35944 non-null  float64
#  493  VALUE_FUEL_QTY_RXT_lag10_lag5          35944 non-null  float64
#  494  FUEL_USED_1_lag10_lag5                 35944 non-null  float64
#  495  NEW_FLIGHT_lag10_lag5                  35944 non-null  object
#  496  FLIGHT_ID_lag10_lag5                   35944 non-null  object
#  497  START_FOB_lag10_lag5                   35944 non-null  float64
#  498  TOTAL_FUEL_USED_lag10_lag5             35944 non-null  float64
#  499  EXPECTED_FOB_lag10_lag5                35944 non-null  float64
#  500  FOB_DIFFERENCE_lag10_lag5              35944 non-null  float64
#  501  FOB_CHANGE_lag10_lag5                  35944 non-null  float64
#  502  EXPECTED_FOB_CHANGE_lag10_lag5         35944 non-null  float64
#  503  FUEL_LEAK_RATE_lag10_lag5              35944 non-null  float64
#  504  TOTAL_FUEL_LW_lag10_lag5               35944 non-null  float64
#  505  TOTAL_FUEL_RW_lag10_lag5               35944 non-null  float64
#  506  LW_RW_DIFF_lag10_lag5                  35944 non-null  float64
#  507  FUEL_IN_TANKS_lag10_lag5               35944 non-null  float64
#  508  CALC_VALUE_FOB_DIFF_lag10_lag5         35944 non-null  float64
#  509  START_FOB_VS_FOB_FUELUSED_lag10_lag5   35944 non-null  float64
#  510  ALTITUDE_DIFF_lag10_lag5               35944 non-null  float64
#  511  UTC_TIME_lag1_lag10                    35944 non-null  datetime64[ns]
#  512  FUEL_USED_2_lag1_lag10                 35944 non-null  float64
#  513  FUEL_USED_3_lag1_lag10                 35944 non-null  float64
#  514  FUEL_USED_4_lag1_lag10                 35944 non-null  float64
#  515  FW_GEO_ALTITUDE_lag1_lag10             35944 non-null  float64
#  516  VALUE_FOB_lag1_lag10                   35944 non-null  float64
#  517  VALUE_FUEL_QTY_CT_lag1_lag10           35944 non-null  float64
#  518  VALUE_FUEL_QTY_FT1_lag1_lag10          35944 non-null  float64
#  519  VALUE_FUEL_QTY_FT2_lag1_lag10          35944 non-null  float64
#  520  VALUE_FUEL_QTY_FT3_lag1_lag10          35944 non-null  float64
#  521  VALUE_FUEL_QTY_FT4_lag1_lag10          35944 non-null  float64
#  522  VALUE_FUEL_QTY_LXT_lag1_lag10          35944 non-null  float64
#  523  VALUE_FUEL_QTY_RXT_lag1_lag10          35944 non-null  float64
#  524  FUEL_USED_1_lag1_lag10                 35944 non-null  float64
#  525  NEW_FLIGHT_lag1_lag10                  35944 non-null  object
#  526  FLIGHT_ID_lag1_lag10                   35944 non-null  object
#  527  START_FOB_lag1_lag10                   35944 non-null  float64
#  528  TOTAL_FUEL_USED_lag1_lag10             35944 non-null  float64
#  529  EXPECTED_FOB_lag1_lag10                35944 non-null  float64
#  530  FOB_DIFFERENCE_lag1_lag10              35944 non-null  float64
#  531  FOB_CHANGE_lag1_lag10                  35944 non-null  float64
#  532  EXPECTED_FOB_CHANGE_lag1_lag10         35944 non-null  float64
#  533  FUEL_LEAK_RATE_lag1_lag10              35944 non-null  float64
#  534  TOTAL_FUEL_LW_lag1_lag10               35944 non-null  float64
#  535  TOTAL_FUEL_RW_lag1_lag10               35944 non-null  float64
#  536  LW_RW_DIFF_lag1_lag10                  35944 non-null  float64
#  537  FUEL_IN_TANKS_lag1_lag10               35944 non-null  float64
#  538  CALC_VALUE_FOB_DIFF_lag1_lag10         35944 non-null  float64
#  539  START_FOB_VS_FOB_FUELUSED_lag1_lag10   35944 non-null  float64
#  540  ALTITUDE_DIFF_lag1_lag10               35944 non-null  float64
#  541  UTC_TIME_lag3_lag10                    35944 non-null  datetime64[ns]
#  542  FUEL_USED_2_lag3_lag10                 35944 non-null  float64
#  543  FUEL_USED_3_lag3_lag10                 35944 non-null  float64
#  544  FUEL_USED_4_lag3_lag10                 35944 non-null  float64
#  545  FW_GEO_ALTITUDE_lag3_lag10             35944 non-null  float64
#  546  VALUE_FOB_lag3_lag10                   35944 non-null  float64
#  547  VALUE_FUEL_QTY_CT_lag3_lag10           35944 non-null  float64
#  548  VALUE_FUEL_QTY_FT1_lag3_lag10          35944 non-null  float64
#  549  VALUE_FUEL_QTY_FT2_lag3_lag10          35944 non-null  float64
#  550  VALUE_FUEL_QTY_FT3_lag3_lag10          35944 non-null  float64
#  551  VALUE_FUEL_QTY_FT4_lag3_lag10          35944 non-null  float64
#  552  VALUE_FUEL_QTY_LXT_lag3_lag10          35944 non-null  float64
#  553  VALUE_FUEL_QTY_RXT_lag3_lag10          35944 non-null  float64
#  554  FUEL_USED_1_lag3_lag10                 35944 non-null  float64
#  555  NEW_FLIGHT_lag3_lag10                  35944 non-null  object
#  556  FLIGHT_ID_lag3_lag10                   35944 non-null  object
#  557  START_FOB_lag3_lag10                   35944 non-null  float64
#  558  TOTAL_FUEL_USED_lag3_lag10             35944 non-null  float64
#  559  EXPECTED_FOB_lag3_lag10                35944 non-null  float64
#  560  FOB_DIFFERENCE_lag3_lag10              35944 non-null  float64
#  561  FOB_CHANGE_lag3_lag10                  35944 non-null  float64
#  562  EXPECTED_FOB_CHANGE_lag3_lag10         35944 non-null  float64
#  563  FUEL_LEAK_RATE_lag3_lag10              35944 non-null  float64
#  564  TOTAL_FUEL_LW_lag3_lag10               35944 non-null  float64
#  565  TOTAL_FUEL_RW_lag3_lag10               35944 non-null  float64
#  566  LW_RW_DIFF_lag3_lag10                  35944 non-null  float64
#  567  FUEL_IN_TANKS_lag3_lag10               35944 non-null  float64
#  568  CALC_VALUE_FOB_DIFF_lag3_lag10         35944 non-null  float64
#  569  START_FOB_VS_FOB_FUELUSED_lag3_lag10   35944 non-null  float64
#  570  ALTITUDE_DIFF_lag3_lag10               35944 non-null  float64
#  571  UTC_TIME_lag5_lag10                    35944 non-null  datetime64[ns]
#  572  FUEL_USED_2_lag5_lag10                 35944 non-null  float64
#  573  FUEL_USED_3_lag5_lag10                 35944 non-null  float64
#  574  FUEL_USED_4_lag5_lag10                 35944 non-null  float64
#  575  FW_GEO_ALTITUDE_lag5_lag10             35944 non-null  float64
#  576  VALUE_FOB_lag5_lag10                   35944 non-null  float64
#  577  VALUE_FUEL_QTY_CT_lag5_lag10           35944 non-null  float64
#  578  VALUE_FUEL_QTY_FT1_lag5_lag10          35944 non-null  float64
#  579  VALUE_FUEL_QTY_FT2_lag5_lag10          35944 non-null  float64
#  580  VALUE_FUEL_QTY_FT3_lag5_lag10          35944 non-null  float64
#  581  VALUE_FUEL_QTY_FT4_lag5_lag10          35944 non-null  float64
#  582  VALUE_FUEL_QTY_LXT_lag5_lag10          35944 non-null  float64
#  583  VALUE_FUEL_QTY_RXT_lag5_lag10          35944 non-null  float64
#  584  FUEL_USED_1_lag5_lag10                 35944 non-null  float64
#  585  NEW_FLIGHT_lag5_lag10                  35944 non-null  object
#  586  FLIGHT_ID_lag5_lag10                   35944 non-null  object
#  587  START_FOB_lag5_lag10                   35944 non-null  float64
#  588  TOTAL_FUEL_USED_lag5_lag10             35944 non-null  float64
#  589  EXPECTED_FOB_lag5_lag10                35944 non-null  float64
#  590  FOB_DIFFERENCE_lag5_lag10              35944 non-null  float64
#  591  FOB_CHANGE_lag5_lag10                  35944 non-null  float64
#  592  EXPECTED_FOB_CHANGE_lag5_lag10         35944 non-null  float64
#  593  FUEL_LEAK_RATE_lag5_lag10              35944 non-null  float64
#  594  TOTAL_FUEL_LW_lag5_lag10               35944 non-null  float64
#  595  TOTAL_FUEL_RW_lag5_lag10               35944 non-null  float64
#  596  LW_RW_DIFF_lag5_lag10                  35944 non-null  float64
#  597  FUEL_IN_TANKS_lag5_lag10               35944 non-null  float64
#  598  CALC_VALUE_FOB_DIFF_lag5_lag10         35944 non-null  float64
#  599  START_FOB_VS_FOB_FUELUSED_lag5_lag10   35944 non-null  float64
#  600  ALTITUDE_DIFF_lag5_lag10               35944 non-null  float64
#  601  UTC_TIME_lag10_lag10                   35944 non-null  datetime64[ns]
#  602  FUEL_USED_2_lag10_lag10                35944 non-null  float64
#  603  FUEL_USED_3_lag10_lag10                35944 non-null  float64
#  604  FUEL_USED_4_lag10_lag10                35944 non-null  float64
#  605  FW_GEO_ALTITUDE_lag10_lag10            35944 non-null  float64
#  606  VALUE_FOB_lag10_lag10                  35944 non-null  float64
#  607  VALUE_FUEL_QTY_CT_lag10_lag10          35944 non-null  float64
#  608  VALUE_FUEL_QTY_FT1_lag10_lag10         35944 non-null  float64
#  609  VALUE_FUEL_QTY_FT2_lag10_lag10         35944 non-null  float64
#  610  VALUE_FUEL_QTY_FT3_lag10_lag10         35944 non-null  float64
#  611  VALUE_FUEL_QTY_FT4_lag10_lag10         35944 non-null  float64
#  612  VALUE_FUEL_QTY_LXT_lag10_lag10         35944 non-null  float64
#  613  VALUE_FUEL_QTY_RXT_lag10_lag10         35944 non-null  float64
#  614  FUEL_USED_1_lag10_lag10                35944 non-null  float64
#  615  NEW_FLIGHT_lag10_lag10                 35944 non-null  object
#  616  FLIGHT_ID_lag10_lag10                  35944 non-null  object
#  617  START_FOB_lag10_lag10                  35944 non-null  float64
#  618  TOTAL_FUEL_USED_lag10_lag10            35944 non-null  float64
#  619  EXPECTED_FOB_lag10_lag10               35944 non-null  float64
#  620  FOB_DIFFERENCE_lag10_lag10             35944 non-null  float64
#  621  FOB_CHANGE_lag10_lag10                 35944 non-null  float64
#  622  EXPECTED_FOB_CHANGE_lag10_lag10        35944 non-null  float64
#  623  FUEL_LEAK_RATE_lag10_lag10             35944 non-null  float64
#  624  TOTAL_FUEL_LW_lag10_lag10              35944 non-null  float64
#  625  TOTAL_FUEL_RW_lag10_lag10              35944 non-null  float64
#  626  LW_RW_DIFF_lag10_lag10                 35944 non-null  float64
#  627  FUEL_IN_TANKS_lag10_lag10              35944 non-null  float64
#  628  CALC_VALUE_FOB_DIFF_lag10_lag10        35944 non-null  float64
#  629  START_FOB_VS_FOB_FUELUSED_lag10_lag10  35944 non-null  float64
#  630  ALTITUDE_DIFF_lag10_lag10              35944 non-null  float64
# dtypes: bool(1), datetime64[ns](21), float64(567), int64(1), object(41)
# memory usage: 173.1+ MB

# %%
# Split data per FLIGHT_ID (to prevent leakage)
train_flights, test_flights = train_test_split(df_balanced['FLIGHT_ID'].unique(), test_size=0.2, random_state=42)

train_df = df_balanced[df_balanced['FLIGHT_ID'].isin(train_flights)]
test_df = df_balanced[df_balanced['FLIGHT_ID'].isin(test_flights)]

# %%
# Reset index (PyCaret needs a clean index)
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %%
# # Initialize PyCaret classification module
clf_setup = setup(
    data=train_df, 
    target=target,
    train_size=0.8,
    session_id=42, 
    fold_strategy="stratifiedkfold", 
    fold=5
)
# Out:
# <style type="text/css">
# #T_8ecb7_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8ecb7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ecb7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8ecb7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ecb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ecb7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8ecb7_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ecb7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8ecb7_row1_col1" class="data row1 col1" >LEAK_FLOW_FLAG</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8ecb7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8ecb7_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8ecb7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8ecb7_row3_col1" class="data row3 col1" >(26106, 631)</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8ecb7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8ecb7_row4_col1" class="data row4 col1" >(26106, 1114)</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8ecb7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8ecb7_row5_col1" class="data row5 col1" >(20884, 1114)</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8ecb7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8ecb7_row6_col1" class="data row6 col1" >(5222, 1114)</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8ecb7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8ecb7_row7_col1" class="data row7 col1" >567</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8ecb7_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_8ecb7_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8ecb7_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_8ecb7_row9_col1" class="data row9 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8ecb7_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_8ecb7_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8ecb7_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_8ecb7_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8ecb7_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_8ecb7_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8ecb7_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_8ecb7_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8ecb7_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_8ecb7_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8ecb7_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_8ecb7_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8ecb7_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_8ecb7_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8ecb7_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_8ecb7_row17_col1" class="data row17 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8ecb7_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_8ecb7_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8ecb7_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_8ecb7_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8ecb7_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_8ecb7_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8ecb7_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_8ecb7_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8ecb7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8ecb7_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_8ecb7_row22_col1" class="data row22 col1" >19cf</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(sort='Recall')
# Out:
# <style type="text/css">
# #T_35629 th {
#   text-align: left;
# }
